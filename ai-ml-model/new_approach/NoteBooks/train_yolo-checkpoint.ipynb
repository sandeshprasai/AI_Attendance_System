# %%
from ultralytics import YOLO
import os

def validate_dataset_splits(data_path):
    """Validate dataset splits and handle empty directories"""
    splits_info = {}
    
    for split in ['train', 'val', 'valid', 'test']:
        split_path = os.path.join(data_path, split)
        
        if os.path.exists(split_path):
            # Check if split has class directories with images
            class_dirs = []
            total_images = 0
            
            if os.path.isdir(split_path):
                for item in os.listdir(split_path):
                    item_path = os.path.join(split_path, item)
                    if os.path.isdir(item_path):
                        # Count images in this class directory
                        images = [f for f in os.listdir(item_path) 
                                 if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]
                        if images:
                            class_dirs.append(item)
                            total_images += len(images)
            
            splits_info[split] = {
                'exists': True,
                'has_classes': len(class_dirs) > 0,
                'class_count': len(class_dirs),
                'image_count': total_images
            }
            
            status = "✅" if len(class_dirs) > 0 else "⚠️  EMPTY"
            print(f"{status} {split}: {len(class_dirs)} classes, {total_images} images")
        else:
            splits_info[split] = {
                'exists': False,
                'has_classes': False,
                'class_count': 0,
                'image_count': 0
            }
            print(f"❌ {split}: Directory not found")
    
    return splits_info

# Dataset path
data_path = r"D:/Final_Semester_Project/AI_Attendance_System/AI_And_ML_Model/datasets/split_dataset"

print("🔍 Validating dataset structure...")
splits_info = validate_dataset_splits(data_path)

# Critical checks
if not splits_info['train']['has_classes']:
    raise ValueError("❌ CRITICAL: Training directory is empty! Cannot train without data.")

# Handle empty/missing validation
if splits_info['val']['has_classes'] or splits_info['valid']['has_classes']:
    # Use existing validation data
    validation_enabled = True
    print("✅ Validation: Using existing validation data")
else:
    # No validation data available
    validation_enabled = False
    print("⚠️  Validation: No validation data found. Training without validation monitoring.")
    print("   Note: Early stopping and LR reduction will be based on training loss.")

# Handle test directory
if splits_info['test']['has_classes']:
    print("✅ Test: Test data available for final evaluation")
else:
    print("ℹ️  Test: No test data - skipping test evaluation")

# Load YOLOv8 classification model from scratch
model = YOLO("yolov8n-cls.yaml")

# Training configuration
train_config = {
    'data': data_path,
    'epochs': 120,
    'imgsz': 224,
    'batch': 8,
    'workers': 4,
    'device': 0,
    
    # Optimizer settings
    'optimizer': "SGD",
    'lr0': 0.01,
    'lrf': 0.01,
    'momentum': 0.937,
    'weight_decay': 0.0005,
    
    # Learning rate scheduling
    'cos_lr': True,
    'warmup_epochs': 3.0,
    'warmup_momentum': 0.8,
    'warmup_bias_lr': 0.1,
    
    # Validation settings
    'val': validation_enabled,
    
    # Early stopping (adjust based on validation availability)
    'patience': 20 if validation_enabled else 30,  # More patience if no validation
    
    # Training options
    'amp': True,
    'verbose': True,
    'save': True,
    'exist_ok': True,
    'pretrained': False,
    'plots': True,
}

print("\n🚀 Starting training with configuration:")
print(f"   - Epochs: {train_config['epochs']}")
print(f"   - Validation: {'ENABLED' if validation_enabled else 'DISABLED'}")
print(f"   - Early stopping patience: {train_config['patience']}")
print(f"   - Learning rate: {train_config['lr0']} with cosine decay")

# Start training
model.train(**train_config)

print("\n📊 Training completed!")
if not splits_info['test']['has_classes']:
    print("💡 Tip: Consider adding test data for proper model evaluation")
# Out:
# 🔍 Validating dataset structure...
# ✅ train: 54 classes, 30240 images
# ❌ val: Directory not found
# ✅ valid: 54 classes, 378 images
# ✅ test: 54 classes, 378 images
# ✅ Validation: Using existing validation data
# ✅ Test: Test data available for final evaluation
# YOLOv8n-cls summary: 56 layers, 2,719,288 parameters, 2,719,288 gradients, 4.4 GFLOPs
#
# 🚀 Starting training with configuration:
#    - Epochs: 120
#    - Validation: ENABLED
#    - Early stopping patience: 20
#    - Learning rate: 0.01 with cosine decay
# Ultralytics 8.3.233  Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=D:/Final_Semester_Project/AI_Attendance_System/AI_And_ML_Model/datasets/split_dataset, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=120, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=False, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\Final_Semester_Project\AI_Attendance_System\ai-ml-model\new_approach\runs\classify\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# train: D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\train... found 30240 images in 54 classes
# val: D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\valid... found 378 images in 54 classes
# test: D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\test... found 378 images in 54 classes
# Overriding model.yaml nc=1000 with nc=54
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    399414  ultralytics.nn.modules.head.Classify         [256, 54]
# YOLOv8n-cls summary: 56 layers, 1,507,462 parameters, 1,507,462 gradients, 3.4 GFLOPs
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 0.90.2 MB/s, size: 16.8 KB)
# train: Scanning D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\train... 30240 images, 0 corrupt: 100% ━━━━━━━━━━━━ 30240/30240 823.7it/s 36.7s<0.0s
# train: New cache created: D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\train.cache
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x000001ACD02385E0>
# Traceback (most recent call last):
#   File "C:\Users\Sandesh Prasai\AppData\Roaming\Python\Python38\site-packages\torch\utils\data\dataloader.py", line 1477, in __del__
#     self._shutdown_workers()
#   File "C:\Users\Sandesh Prasai\AppData\Roaming\Python\Python38\site-packages\torch\utils\data\dataloader.py", line 1435, in _shutdown_workers
#     if self._persistent_workers or self._workers_status[worker_id]:
# AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
# val: Fast image access  (ping: 0.20.1 ms, read: 1.70.4 MB/s, size: 14.5 KB)
# val: Scanning D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\valid... 378 images, 0 corrupt: 100% ━━━━━━━━━━━━ 378/378 187.3Kit/s 0.0s
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 4 dataloader workers
# Logging results to D:\Final_Semester_Project\AI_Attendance_System\ai-ml-model\new_approach\runs\classify\train
# Starting training for 120 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/120     0.246G      3.911          8        224: 100% ━━━━━━━━━━━━ 3780/3780 25.9it/s 2:26<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 34.2it/s 0.7s0.1s
#                    all      0.185      0.415
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/120     0.246G      3.071          8        224: 100% ━━━━━━━━━━━━ 3780/3780 28.2it/s 2:14<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 67.3it/s 0.4s0.0s
#                    all      0.458      0.788
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/120     0.246G      2.318          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.8it/s 1:59<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 66.9it/s 0.4s0.1s
#                    all      0.601      0.894
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/120     0.246G       1.87          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.4it/s 2:01<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 70.7it/s 0.3s0.2s
#                    all      0.693      0.929
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/120     0.246G      1.453          8        224: 100% ━━━━━━━━━━━━ 3780/3780 29.0it/s 2:10<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 48.2it/s 0.5s0.1s
#                    all      0.767      0.942
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/120     0.246G       1.21          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.8it/s 1:59<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.7it/s 0.4s0.1s
#                    all      0.847      0.952
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/120     0.246G      1.023          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.2it/s 2:01<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 57.2it/s 0.4s0.1s
#                    all      0.817      0.958
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/120     0.246G     0.8848          8        224: 100% ━━━━━━━━━━━━ 3780/3780 30.9it/s 2:03<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 63.7it/s 0.4s0.1s
#                    all      0.833      0.974
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/120     0.246G     0.7903          8        224: 100% ━━━━━━━━━━━━ 3780/3780 28.5it/s 2:13<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 45.6it/s 0.5s0.1s
#                    all      0.865      0.966
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/120     0.246G     0.7022          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.3it/s 2:01<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 65.2it/s 0.4s0.1s
#                    all      0.905      0.958
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/120     0.246G     0.6395          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.4it/s 1:57<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 58.7it/s 0.4s0.1s
#                    all      0.868      0.966
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/120     0.246G     0.5992          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.6it/s 1:56<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 71.7it/s 0.3s0.2s
#                    all      0.881      0.976
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/120     0.246G     0.5645          8        224: 100% ━━━━━━━━━━━━ 3780/3780 34.9it/s 1:48<0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 75.2it/s 0.3s0.2s
#                    all      0.902      0.976
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/120     0.246G     0.5139          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.8it/s 1:55<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 60.6it/s 0.4s0.1s
#                    all      0.907      0.971
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/120     0.246G     0.4986          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.6it/s 1:60<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 66.9it/s 0.4s0.1s
#                    all      0.892      0.976
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/120     0.246G     0.4617          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.3it/s 1:57<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.8it/s 0.4s0.1s
#                    all       0.91      0.976
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/120     0.246G     0.4376          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.0it/s 1:58<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 55.9it/s 0.4s0.1s
#                    all      0.921      0.974
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/120     0.246G     0.4066          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.3it/s 1:57<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 68.9it/s 0.3s0.0s
#                    all      0.915      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/120     0.246G     0.3829          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.1it/s 1:58<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 63.8it/s 0.4s0.0s
#                    all      0.915      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/120     0.246G     0.3771          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.1it/s 1:58<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 62.9it/s 0.4s0.1s
#                    all      0.921      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/120     0.246G     0.3733          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.2it/s 1:57<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 65.6it/s 0.4s0.0s
#                    all      0.921      0.976
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/120     0.246G     0.3619          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.0it/s 1:58<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.3it/s 0.4s0.1s
#                    all      0.921      0.989
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/120     0.246G      0.344          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.3it/s 2:01<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 63.3it/s 0.4s0.1s
#                    all      0.931      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/120     0.246G     0.3304          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.8it/s 1:59<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 66.1it/s 0.4s0.0s
#                    all      0.929      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/120     0.246G     0.3182          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.8it/s 1:59<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.0it/s 0.4s0.1s
#                    all      0.934      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/120     0.246G     0.3059          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.1it/s 1:58<0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 65.7it/s 0.4s0.1s
#                    all      0.929      0.976
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/120     0.246G     0.3016          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.6it/s 1:59<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 64.1it/s 0.4s0.1s
#                    all      0.934      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/120     0.246G     0.2935          8        224: 100% ━━━━━━━━━━━━ 3780/3780 29.9it/s 2:06<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 59.5it/s 0.4s0.1s
#                    all      0.934      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/120     0.246G      0.288          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.6it/s 1:60<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.2it/s 0.4s0.1s
#                    all      0.931      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/120     0.246G     0.2686          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.8it/s 1:59<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 65.8it/s 0.4s0.1s
#                    all      0.929      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      31/120     0.246G     0.2736          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.5it/s 1:60<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.4it/s 0.4s0.1s
#                    all      0.926      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/120     0.246G     0.2624          8        224: 100% ━━━━━━━━━━━━ 3780/3780 24.7it/s 2:33<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.2it/s 0.6s0.1s
#                    all      0.929      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      33/120     0.246G     0.2598          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.1it/s 2:02<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 55.4it/s 0.4s0.1s
#                    all      0.929      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      34/120     0.246G     0.2498          8        224: 100% ━━━━━━━━━━━━ 3780/3780 28.4it/s 2:13<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 70.0it/s 0.3s0.0s
#                    all      0.934      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      35/120     0.246G     0.2365          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.5it/s 1:60<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 62.3it/s 0.4s0.1s
#                    all      0.934      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      36/120     0.246G     0.2339          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.9it/s 1:59<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 63.3it/s 0.4s0.1s
#                    all      0.937      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/120     0.246G     0.2281          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.6it/s 1:60<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 60.7it/s 0.4s0.1s
#                    all      0.939      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      38/120     0.246G     0.2265          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.4it/s 2:00<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 59.0it/s 0.4s0.1s
#                    all      0.937      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/120     0.246G     0.2247          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.0it/s 1:58<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 65.3it/s 0.4s0.0s
#                    all      0.937      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      40/120     0.246G     0.2226          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.7it/s 1:59<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 64.6it/s 0.4s0.0s
#                    all      0.939      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      41/120     0.246G     0.2119          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.7it/s 1:59<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 64.1it/s 0.4s0.1s
#                    all      0.942      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      42/120     0.246G     0.2119          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.0it/s 2:02<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 60.0it/s 0.4s0.1s
#                    all      0.944      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      43/120     0.246G     0.2049          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.3it/s 2:01<0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 63.3it/s 0.4s0.1s
#                    all      0.944      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      44/120     0.246G     0.2025          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.6it/s 1:60<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 67.5it/s 0.4s0.0s
#                    all      0.944      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      45/120     0.246G     0.1994          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.7it/s 1:59<0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 62.5it/s 0.4s0.1s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      46/120     0.246G     0.1861          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.6it/s 1:60<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.7it/s 0.4s0.1s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      47/120     0.246G     0.1884          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.3it/s 2:01<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 64.0it/s 0.4s0.1s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      48/120     0.246G     0.1878          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.5it/s 2:00<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 64.9it/s 0.4s0.1s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      49/120     0.246G      0.183          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.6it/s 1:60<0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.8it/s 0.4s0.1s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      50/120     0.246G     0.1765          8        224: 100% ━━━━━━━━━━━━ 3780/3780 31.8it/s 1:59<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 66.2it/s 0.4s0.0s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      51/120     0.246G     0.1724          8        224: 100% ━━━━━━━━━━━━ 3780/3780 27.7it/s 2:16<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 68.3it/s 0.4s0.0s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      52/120     0.246G     0.1706          8        224: 100% ━━━━━━━━━━━━ 3780/3780 30.3it/s 2:05<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 58.2it/s 0.4s0.1s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      53/120     0.246G     0.1611          8        224: 100% ━━━━━━━━━━━━ 3780/3780 30.7it/s 2:03<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 64.1it/s 0.4s0.1s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      54/120     0.246G     0.1566          8        224: 100% ━━━━━━━━━━━━ 3780/3780 26.1it/s 2:25<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 49.0it/s 0.5s0.1s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      55/120     0.246G     0.1579          8        224: 100% ━━━━━━━━━━━━ 3780/3780 21.6it/s 2:55<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 51.3it/s 0.5s0.0s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      56/120     0.246G     0.1555          8        224: 100% ━━━━━━━━━━━━ 3780/3780 22.5it/s 2:48<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.8it/s 0.6s0.1s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      57/120     0.246G     0.1538          8        224: 100% ━━━━━━━━━━━━ 3780/3780 20.1it/s 3:09<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.2it/s 0.6s0.1s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      58/120     0.246G     0.1467          8        224: 100% ━━━━━━━━━━━━ 3780/3780 21.2it/s 2:58<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 47.6it/s 0.5s0.1s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      59/120     0.246G     0.1479          8        224: 100% ━━━━━━━━━━━━ 3780/3780 20.9it/s 3:00<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 39.2it/s 0.6s0.1s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      60/120     0.246G      0.141          8        224: 100% ━━━━━━━━━━━━ 3780/3780 21.7it/s 2:54<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 40.6it/s 0.6s0.1s
#                    all      0.952      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#      61/120     0.246G     0.1405          8        224: 100% ━━━━━━━━━━━━ 3780/3780 23.0it/s 2:45<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 46.7it/s 0.5s0.1s
#                    all      0.952      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#      62/120     0.246G     0.1369          8        224: 100% ━━━━━━━━━━━━ 3780/3780 20.7it/s 3:03<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 44.5it/s 0.5s0.2s
#                    all      0.952      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      63/120     0.246G     0.1297          8        224: 100% ━━━━━━━━━━━━ 3780/3780 22.3it/s 2:49<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 48.0it/s 0.5s0.1s
#                    all      0.952      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      64/120     0.246G     0.1258          8        224: 100% ━━━━━━━━━━━━ 3780/3780 21.5it/s 2:55<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 46.9it/s 0.5s0.1s
#                    all      0.952      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      65/120     0.246G     0.1215          8        224: 74% ━━━━━━━━╸─── 2794/3780 23.4it/s 2:02<42.1s
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      68/120     0.246G     0.1092          8        224: 100% ━━━━━━━━━━━━ 3780/3780 21.1it/s 2:60<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 48.0it/s 0.5s0.0s
#                    all      0.944      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      69/120     0.246G     0.1081          8        224: 100% ━━━━━━━━━━━━ 3780/3780 23.8it/s 2:39<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 49.8it/s 0.5s0.1s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      70/120     0.246G     0.1127          8        224: 100% ━━━━━━━━━━━━ 3780/3780 23.6it/s 2:40<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 48.9it/s 0.5s0.1s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      71/120     0.246G     0.1018          8        224: 100% ━━━━━━━━━━━━ 3780/3780 29.9it/s 2:06<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 56.0it/s 0.4s0.1s
#                    all      0.947      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#      72/120     0.246G     0.1016          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.5it/s 1:56<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 67.7it/s 0.4s0.0s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      73/120     0.246G     0.1001          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.4it/s 1:57<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 63.0it/s 0.4s0.1s
#                    all       0.95      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      74/120     0.246G     0.1004          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.8it/s 1:55<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 64.2it/s 0.4s0.1s
#                    all       0.95      0.976
#
#       Epoch    GPU_mem       loss  Instances       Size
#      75/120     0.246G    0.08945          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.2it/s 1:57<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.2it/s 0.4s0.1s
#                    all       0.95      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      76/120     0.246G    0.09108          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.6it/s 1:56<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 69.9it/s 0.3s0.0s
#                    all      0.947      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      77/120     0.246G    0.08772          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.4it/s 1:57<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 70.3it/s 0.3s0.0s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      78/120     0.246G    0.08764          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.6it/s 1:56<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 62.0it/s 0.4s0.1s
#                    all      0.947      0.979
#
#       Epoch    GPU_mem       loss  Instances       Size
#      79/120     0.246G    0.08574          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.4it/s 1:57<0.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 64.4it/s 0.4s0.1s
#                    all      0.947      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      80/120     0.246G    0.08049          8        224: 100% ━━━━━━━━━━━━ 3780/3780 32.3it/s 1:57<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 61.0it/s 0.4s0.1s
#                    all      0.947      0.981
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 60, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 80 epochs completed in 2.937 hours.
# Optimizer stripped from D:\Final_Semester_Project\AI_Attendance_System\ai-ml-model\new_approach\runs\classify\train\weights\last.pt, 3.1MB
# Optimizer stripped from D:\Final_Semester_Project\AI_Attendance_System\ai-ml-model\new_approach\runs\classify\train\weights\best.pt, 3.1MB
#
# Validating D:\Final_Semester_Project\AI_Attendance_System\ai-ml-model\new_approach\runs\classify\train\weights\best.pt...
# Ultralytics 8.3.233  Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,504,054 parameters, 0 gradients, 3.3 GFLOPs
# train: D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\train... found 30240 images in 54 classes
# val: D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\valid... found 378 images in 54 classes
# test: D:\Final_Semester_Project\AI_Attendance_System\AI_And_ML_Model\datasets\split_dataset\test... found 378 images in 54 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 33.0it/s 0.7s0.1s
#                    all      0.952      0.984
# Speed: 0.2ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to D:\Final_Semester_Project\AI_Attendance_System\ai-ml-model\new_approach\runs\classify\train
#
# 📊 Training completed!

# %%
from ultralytics import YOLO
import os
from pathlib import Path

# Load your trained model
model = YOLO('yolo11n.pt')

# Path to your folder
folder_path = 'D:\\New folder'

# Classify all images in the folder
results = model.predict(
    source=folder_path,
    save=True,
    save_txt=True,
    save_conf=True,
    exist_ok=True  # Overwrite existing results
)

# Process results with error handling
results_summary = []
successful_predictions = 0

for i, result in enumerate(results):
    if result is None or result.probs is None:
        print(f"⚠️  No prediction for image {i+1}")
        continue
    
    try:
        # Get prediction details
        top1_idx = result.probs.top1
        top1_conf = result.probs.top1conf.item()  # Convert to Python float
        class_name = result.names[top1_idx]
        
        results_summary.append({
            'image': os.path.basename(result.path),
            'predicted_class': class_name,
            'confidence': f"{top1_conf:.4f}",
            'class_id': top1_idx
        })
        
        print(f"✅ Image: {os.path.basename(result.path)}")
        print(f"   Prediction: {class_name} (Confidence: {top1_conf:.4f})")
        print("-" * 50)
        successful_predictions += 1
        
    except AttributeError as e:
        print(f"❌ Error processing image {i+1}: {e}")
        continue

print(f"\n📊 Summary: {successful_predictions}/{len(results)} images classified successfully")

# Display results
if results_summary:
    print("\n📋 Classification Results:")
    for item in results_summary:
        print(f"{item['image']} -> {item['predicted_class']} ({item['confidence']})")

# %%
pip install pandas

# %% [raw]
# from ultralytics import YOLO
#
# # Test model loading
# model = YOLO('yolo11n.pt')
# print("✅ Model loaded successfully!")
# print(f"Model type: {type(model)}")
#
# # Test on single image first
# test_result = model.predict(r"D:\New folder\vk.png")
# print(f"Single test result: {test_result}")
