# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import cv2
import os
import numpy as np
import tensorflow as tf
from pathlib import Path
from collections import deque, Counter
from scipy.spatial.distance import cosine

# -------------------------------
# CONFIG
# -------------------------------
NUM_IMAGES = 300
FACES_DIR = Path("data/faces")
EMB_DIR = Path("data/embeddings")
EMB_DIR.mkdir(exist_ok=True)

MODEL_PATH = r'/home/sandeshprasai/Final_Semester_Project/AI_Attendance_System/ai-ml-model/src/models/CNN/best_face_model.keras'

# -------------------------------
# LOAD MODEL
# -------------------------------
model = tf.keras.models.load_model(MODEL_PATH)

# -------------------------------
# FACE EXTRACTION (for enrollment)
# -------------------------------
def extract_face(img):
    # For controlled enrollment, just resize the whole image
    face = cv2.resize(img, (112, 112))
    return face

def get_embedding(face):
    face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
    face = face.astype("float32") / 255.0
    face = (face - 0.5) / 0.5
    face = np.expand_dims(face, axis=0)
    emb = model.predict(face, verbose=0)
    return emb[0]

# -------------------------------
# STEP 1: CAPTURE IMAGES
# -------------------------------
person_name = input("Enter person name: ").strip()
person_dir = FACES_DIR / person_name
person_dir.mkdir(parents=True, exist_ok=True)

cap = cv2.VideoCapture("http://10.61.203.27:4747/video")
count = 0
print("Press 'c' to capture | 'q' to quit")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # rotate if camera is rotated
    frame = cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)

    cv2.imshow("Capture Face", frame)
    key = cv2.waitKey(1) & 0xFF

    if key == ord('c'):
        path = person_dir / f"img_{count}.jpg"
        cv2.imwrite(str(path), frame)
        print(f"Saved {path}")
        count += 1

    if key == ord('q') or count >= NUM_IMAGES:
        break

cap.release()
cv2.destroyAllWindows()

# -------------------------------
# STEP 2: GENERATE EMBEDDINGS
# -------------------------------
embeddings = []
for img_path in person_dir.glob("*.jpg"):
    img = cv2.imread(str(img_path))
    face = extract_face(img)
    if face is None:
        print(f"Failed to extract face from {img_path}")
        continue
    embeddings.append(get_embedding(face))

if len(embeddings) > 0:
    reference_embedding = np.mean(np.array(embeddings), axis=0)
    emb_path = EMB_DIR / f"{person_name}.npy"
    np.save(emb_path, reference_embedding)
    print(f"Saved embedding: {emb_path}")
else:
    print("No embeddings generated. Check captured images.")

# -------------------------------
# STEP 3: LOAD ALL EMBEDDINGS
# -------------------------------
known_embeddings = {}
for emb_file in EMB_DIR.glob("*.npy"):
    name = emb_file.stem
    known_embeddings[name] = np.load(emb_file)
print(f"Loaded embeddings for: {list(known_embeddings.keys())}")

# -------------------------------
# RECOGNIZE FACE USING COSINE SIMILARITY
# -------------------------------
# Out:
# Press 'c' to capture | 'q' to quit
# Saved data/faces/santu/img_0.jpg
# Saved data/faces/santu/img_1.jpg
# Saved data/faces/santu/img_2.jpg
# Saved data/faces/santu/img_3.jpg
# Saved data/faces/santu/img_4.jpg
# Saved data/faces/santu/img_5.jpg
# Saved data/faces/santu/img_6.jpg
# Saved data/faces/santu/img_7.jpg
# Saved data/faces/santu/img_8.jpg
# Saved data/faces/santu/img_9.jpg
# Saved data/faces/santu/img_10.jpg
# Saved data/faces/santu/img_11.jpg
# Saved data/faces/santu/img_12.jpg
# Saved data/faces/santu/img_13.jpg
# Saved data/faces/santu/img_14.jpg
# Saved data/faces/santu/img_15.jpg
# Saved data/faces/santu/img_16.jpg
# Saved data/faces/santu/img_17.jpg
# Saved data/faces/santu/img_18.jpg
# Saved data/faces/santu/img_19.jpg
# Saved data/faces/santu/img_20.jpg
# Saved data/faces/santu/img_21.jpg
# Saved data/faces/santu/img_22.jpg
# Saved data/faces/santu/img_23.jpg
# Saved data/faces/santu/img_24.jpg
# Saved data/faces/santu/img_25.jpg
# Saved data/faces/santu/img_26.jpg
# Saved data/faces/santu/img_27.jpg
# Saved data/faces/santu/img_28.jpg
# Saved data/faces/santu/img_29.jpg
# Saved data/faces/santu/img_30.jpg
# Saved data/faces/santu/img_31.jpg
# Saved data/faces/santu/img_32.jpg
# Saved data/faces/santu/img_33.jpg
# Saved data/faces/santu/img_34.jpg
# Saved data/faces/santu/img_35.jpg
# Saved data/faces/santu/img_36.jpg
# Saved data/faces/santu/img_37.jpg
# Saved data/faces/santu/img_38.jpg
# Saved data/faces/santu/img_39.jpg
# Saved data/faces/santu/img_40.jpg
# Saved data/faces/santu/img_41.jpg
# Saved data/faces/santu/img_42.jpg
# Saved data/faces/santu/img_43.jpg
# Saved data/faces/santu/img_44.jpg
# Saved data/faces/santu/img_45.jpg
# Saved data/faces/santu/img_46.jpg
# Saved data/faces/santu/img_47.jpg
# Saved data/faces/santu/img_48.jpg
# Saved data/faces/santu/img_49.jpg
# Saved data/faces/santu/img_50.jpg
# Saved data/faces/santu/img_51.jpg
# Saved data/faces/santu/img_52.jpg
# Saved data/faces/santu/img_53.jpg
# Saved data/faces/santu/img_54.jpg
# Saved data/faces/santu/img_55.jpg
# Saved data/faces/santu/img_56.jpg
# Saved data/faces/santu/img_57.jpg
# Saved data/faces/santu/img_58.jpg
# Saved data/faces/santu/img_59.jpg
# Saved data/faces/santu/img_60.jpg
# Saved data/faces/santu/img_61.jpg
# Saved data/faces/santu/img_62.jpg
# Saved data/faces/santu/img_63.jpg
# Saved data/faces/santu/img_64.jpg
# Saved data/faces/santu/img_65.jpg
# Saved data/faces/santu/img_66.jpg
# Saved data/faces/santu/img_67.jpg
# Saved data/faces/santu/img_68.jpg
# Saved data/faces/santu/img_69.jpg
# Saved data/faces/santu/img_70.jpg
# Saved data/faces/santu/img_71.jpg
# Saved data/faces/santu/img_72.jpg
# Saved data/faces/santu/img_73.jpg
# Saved data/faces/santu/img_74.jpg
# Saved data/faces/santu/img_75.jpg
# Saved data/faces/santu/img_76.jpg
# Saved data/faces/santu/img_77.jpg
# Saved data/faces/santu/img_78.jpg
# Saved data/faces/santu/img_79.jpg
# Saved data/faces/santu/img_80.jpg
# Saved data/faces/santu/img_81.jpg
# Saved data/faces/santu/img_82.jpg
# Saved data/faces/santu/img_83.jpg
# Saved data/faces/santu/img_84.jpg
# Saved data/faces/santu/img_85.jpg
# Saved data/faces/santu/img_86.jpg
# Saved data/faces/santu/img_87.jpg
# Saved data/faces/santu/img_88.jpg
# Saved data/faces/santu/img_89.jpg
# Saved data/faces/santu/img_90.jpg
# Saved data/faces/santu/img_91.jpg
# Saved data/faces/santu/img_92.jpg
# Saved data/faces/santu/img_93.jpg
# Saved data/faces/santu/img_94.jpg
# Saved data/faces/santu/img_95.jpg
# Saved data/faces/santu/img_96.jpg
# Saved data/faces/santu/img_97.jpg
# Saved data/faces/santu/img_98.jpg
# Saved data/faces/santu/img_99.jpg
# Saved data/faces/santu/img_100.jpg
# Saved data/faces/santu/img_101.jpg
# Saved data/faces/santu/img_102.jpg
# Saved data/faces/santu/img_103.jpg
# Saved data/faces/santu/img_104.jpg
# Saved data/faces/santu/img_105.jpg
# Saved data/faces/santu/img_106.jpg
# Saved data/faces/santu/img_107.jpg
# Saved data/faces/santu/img_108.jpg
# Saved data/faces/santu/img_109.jpg
# Saved data/faces/santu/img_110.jpg
# Saved data/faces/santu/img_111.jpg
# Saved data/faces/santu/img_112.jpg
# Saved data/faces/santu/img_113.jpg
# Saved data/faces/santu/img_114.jpg
# Saved data/faces/santu/img_115.jpg
# Saved data/faces/santu/img_116.jpg
# Saved data/faces/santu/img_117.jpg
# Saved data/faces/santu/img_118.jpg
# Saved data/faces/santu/img_119.jpg
# Saved data/faces/santu/img_120.jpg
# Saved data/faces/santu/img_121.jpg
# Saved data/faces/santu/img_122.jpg
# Saved data/faces/santu/img_123.jpg
# Saved data/faces/santu/img_124.jpg
# Saved data/faces/santu/img_125.jpg
# Saved data/faces/santu/img_126.jpg
# Saved data/faces/santu/img_127.jpg
# Saved data/faces/santu/img_128.jpg
# Saved data/faces/santu/img_129.jpg
# Saved data/faces/santu/img_130.jpg
# Saved data/faces/santu/img_131.jpg
# Saved data/faces/santu/img_132.jpg
# Saved data/faces/santu/img_133.jpg
# Saved data/faces/santu/img_134.jpg
# Saved data/faces/santu/img_135.jpg
# Saved data/faces/santu/img_136.jpg
# Saved data/faces/santu/img_137.jpg
# Saved data/faces/santu/img_138.jpg
# Saved data/faces/santu/img_139.jpg
# Saved data/faces/santu/img_140.jpg
# Saved data/faces/santu/img_141.jpg
# Saved data/faces/santu/img_142.jpg
# Saved data/faces/santu/img_143.jpg
# Saved data/faces/santu/img_144.jpg
# Saved data/faces/santu/img_145.jpg
# Saved data/faces/santu/img_146.jpg
# Saved data/faces/santu/img_147.jpg
# Saved data/faces/santu/img_148.jpg
# Saved data/faces/santu/img_149.jpg
# Saved data/faces/santu/img_150.jpg
# Saved data/faces/santu/img_151.jpg
# Saved data/faces/santu/img_152.jpg
# Saved data/faces/santu/img_153.jpg
# Saved data/faces/santu/img_154.jpg
# Saved data/faces/santu/img_155.jpg
# Saved data/faces/santu/img_156.jpg
# Saved data/faces/santu/img_157.jpg
# Saved data/faces/santu/img_158.jpg
# Saved data/faces/santu/img_159.jpg
# Saved data/faces/santu/img_160.jpg
# Saved data/faces/santu/img_161.jpg
# Saved data/faces/santu/img_162.jpg
# Saved data/faces/santu/img_163.jpg
# Saved data/faces/santu/img_164.jpg
# Saved data/faces/santu/img_165.jpg
# Saved data/faces/santu/img_166.jpg
# Saved data/faces/santu/img_167.jpg
# Saved data/faces/santu/img_168.jpg
# Saved data/faces/santu/img_169.jpg
# Saved data/faces/santu/img_170.jpg
# Saved data/faces/santu/img_171.jpg
# Saved data/faces/santu/img_172.jpg
# Saved data/faces/santu/img_173.jpg
# Saved data/faces/santu/img_174.jpg
# Saved data/faces/santu/img_175.jpg
# Saved data/faces/santu/img_176.jpg
# Saved data/faces/santu/img_177.jpg
# Saved data/faces/santu/img_178.jpg
# Saved data/faces/santu/img_179.jpg
# Saved data/faces/santu/img_180.jpg
# Saved data/faces/santu/img_181.jpg
# Saved data/faces/santu/img_182.jpg
# Saved data/faces/santu/img_183.jpg
# Saved data/faces/santu/img_184.jpg
# Saved data/faces/santu/img_185.jpg
# Saved data/faces/santu/img_186.jpg
# Saved data/faces/santu/img_187.jpg
# Saved data/faces/santu/img_188.jpg
# Saved data/faces/santu/img_189.jpg
# Saved data/faces/santu/img_190.jpg
# Saved data/faces/santu/img_191.jpg
# Saved data/faces/santu/img_192.jpg
# Saved data/faces/santu/img_193.jpg
# Saved data/faces/santu/img_194.jpg
# Saved data/faces/santu/img_195.jpg
# Saved data/faces/santu/img_196.jpg
# Saved data/faces/santu/img_197.jpg
# Saved data/faces/santu/img_198.jpg
# Saved data/faces/santu/img_199.jpg
# Saved data/faces/santu/img_200.jpg
# Saved data/faces/santu/img_201.jpg
# Saved data/faces/santu/img_202.jpg
# Saved data/faces/santu/img_203.jpg
# Saved data/faces/santu/img_204.jpg
# Saved data/faces/santu/img_205.jpg
# Saved data/faces/santu/img_206.jpg
# Saved data/faces/santu/img_207.jpg
# Saved data/faces/santu/img_208.jpg
# Saved data/faces/santu/img_209.jpg
# Saved data/faces/santu/img_210.jpg
# Saved data/faces/santu/img_211.jpg
# Saved data/faces/santu/img_212.jpg
# Saved data/faces/santu/img_213.jpg
# Saved data/faces/santu/img_214.jpg
# Saved data/faces/santu/img_215.jpg
# Saved data/faces/santu/img_216.jpg
# Saved data/faces/santu/img_217.jpg
# Saved data/faces/santu/img_218.jpg
# Saved data/faces/santu/img_219.jpg
# Saved data/faces/santu/img_220.jpg
# Saved data/faces/santu/img_221.jpg
# Saved data/faces/santu/img_222.jpg
# Saved data/faces/santu/img_223.jpg
# Saved data/faces/santu/img_224.jpg
# Saved data/faces/santu/img_225.jpg
# Saved data/faces/santu/img_226.jpg
# Saved data/faces/santu/img_227.jpg
# Saved data/faces/santu/img_228.jpg
# Saved data/faces/santu/img_229.jpg
# Saved data/faces/santu/img_230.jpg
# Saved data/faces/santu/img_231.jpg
# Saved data/faces/santu/img_232.jpg
# Saved data/faces/santu/img_233.jpg
# Saved data/faces/santu/img_234.jpg
# Saved data/faces/santu/img_235.jpg
# Saved data/faces/santu/img_236.jpg
# Saved data/faces/santu/img_237.jpg
# Saved data/faces/santu/img_238.jpg
# Saved data/faces/santu/img_239.jpg
# Saved data/faces/santu/img_240.jpg
# Saved data/faces/santu/img_241.jpg
# Saved data/faces/santu/img_242.jpg
# Saved data/faces/santu/img_243.jpg
# Saved data/faces/santu/img_244.jpg
# Saved data/faces/santu/img_245.jpg
# Saved data/faces/santu/img_246.jpg
# Saved data/faces/santu/img_247.jpg
# Saved data/faces/santu/img_248.jpg
# Saved data/faces/santu/img_249.jpg
# Saved data/faces/santu/img_250.jpg
# Saved data/faces/santu/img_251.jpg
# Saved data/faces/santu/img_252.jpg
# Saved data/faces/santu/img_253.jpg
# Saved data/faces/santu/img_254.jpg
# Saved data/faces/santu/img_255.jpg
# Saved data/faces/santu/img_256.jpg
# Saved data/faces/santu/img_257.jpg
# Saved data/faces/santu/img_258.jpg
# Saved data/faces/santu/img_259.jpg
# Saved data/faces/santu/img_260.jpg
# Saved data/faces/santu/img_261.jpg
# Saved data/faces/santu/img_262.jpg
# Saved data/faces/santu/img_263.jpg
# Saved data/faces/santu/img_264.jpg
# Saved data/faces/santu/img_265.jpg
# Saved data/faces/santu/img_266.jpg
# Saved data/faces/santu/img_267.jpg
# Saved data/faces/santu/img_268.jpg
# Saved data/faces/santu/img_269.jpg
# Saved data/faces/santu/img_270.jpg
# Saved data/faces/santu/img_271.jpg
# Saved data/faces/santu/img_272.jpg
# Saved data/faces/santu/img_273.jpg
# Saved data/faces/santu/img_274.jpg
# Saved data/faces/santu/img_275.jpg
# Saved data/faces/santu/img_276.jpg
# Saved data/faces/santu/img_277.jpg
# Saved data/faces/santu/img_278.jpg
# Saved data/faces/santu/img_279.jpg
# Saved data/faces/santu/img_280.jpg
# Saved data/faces/santu/img_281.jpg
# Saved data/faces/santu/img_282.jpg
# Saved data/faces/santu/img_283.jpg
# Saved data/faces/santu/img_284.jpg
# Saved data/faces/santu/img_285.jpg
# Saved data/faces/santu/img_286.jpg
# Saved data/faces/santu/img_287.jpg
# Saved data/faces/santu/img_288.jpg
# Saved data/faces/santu/img_289.jpg
# Saved data/faces/santu/img_290.jpg
# Saved data/faces/santu/img_291.jpg
# Saved data/faces/santu/img_292.jpg
# Saved data/faces/santu/img_293.jpg
# Saved data/faces/santu/img_294.jpg
# Saved data/faces/santu/img_295.jpg
# Saved data/faces/santu/img_296.jpg
# Saved data/faces/santu/img_297.jpg
# Saved data/faces/santu/img_298.jpg
# Saved data/faces/santu/img_299.jpg
# Saved embedding: data/embeddings/santu.npy
# Loaded embeddings for: ['saurab', 'santu', 'sandesh_glasses']

# %%
def recognize_face(emb, known_embeddings, threshold=0.8):
    best_match = "Unknown"
    best_score = float('inf')  # We use cosine distance, so lower is better
    for name, known_emb in known_embeddings.items():
        dist = cosine(emb, known_emb)  # Cosine similarity measures how close the embeddings are
        if dist < best_score:
            best_score = dist
            best_match = name

    # If the best match's score is below the threshold, we consider it as recognized
    if best_score < threshold:
        return best_match, 1 - best_score  # Cosine similarity is 1 - cosine distance

    return "Unknown", 0.0  # If no match is found with high enough confidence

# -------------------------------
# STEP 4: LIVE FACE RECOGNITION
# -------------------------------
recent_predictions = deque(maxlen=5)
SIMILARITY_THRESHOLD = 0.8  # increase threshold for more confident recognition

cap = cv2.VideoCapture("http://10.61.203.27:4747/video")
while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)

    face = extract_face(frame)
    if face is not None:
        emb = get_embedding(face)
        name, score = recognize_face(emb, known_embeddings, threshold=SIMILARITY_THRESHOLD)
        recent_predictions.append(name)

        # Majority vote for steady output
        name_smoothed = Counter(recent_predictions).most_common(1)[0][0]

        label = f"{name_smoothed} ({score:.2f})"
        color = (0, 255, 0) if name_smoothed != "Unknown" else (0, 0, 255)
        cv2.putText(frame, label, (30, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)

    cv2.imshow("Face Recognition", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
