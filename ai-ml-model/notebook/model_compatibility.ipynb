# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)

MODEL_PATH = r"/home/sandeshprasai/Final_Semester_Project/AI_Attendance_System/ai-ml-model/src/models/best_face_model.keras"  

try:
    model = tf.keras.models.load_model(
        MODEL_PATH,
        compile=False  
    )
    print("SUCCESS: Model loaded correctly in TF 2.19")
    model.summary()
except Exception as e:
    print("FAILURE: Model is NOT compatible with TF 2.19")
    print(type(e).__name__)
    print(e)
# Out:
# TensorFlow version: 2.19.0
# SUCCESS: Model loaded correctly in TF 2.19
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 112, 112, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 112, 112, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ...

# %%
import tensorflow as tf

# Check TensorFlow version
print("TensorFlow version:", tf.__version__)

# List all physical GPUs detected by TensorFlow
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs detected: {len(gpus)}")
    for gpu in gpus:
        print(" -", gpu)
else:
    print("No GPU detected")

# Optional: Check if TensorFlow can actually use GPU
print("Is TensorFlow built with CUDA GPU support:", tf.test.is_built_with_cuda())
print("Is GPU available for TensorFlow:", tf.test.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None))
