# %%
# ============================================================
# CELL 1  –  Imports & GPU confirmation
# ============================================================
import os, math, json, random
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
import matplotlib
matplotlib.use('Agg')                           # safe for Kaggle kernel
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from sklearn.metrics import (
    roc_auc_score, roc_curve, precision_recall_curve,
    average_precision_score
)
from sklearn.model_selection import train_test_split
from PIL import Image
import warnings; warnings.filterwarnings('ignore')
from tqdm import tqdm
# ── GPU check ──
print(f"TensorFlow : {tf.__version__}")
print(f"GPUs found : {tf.config.list_physical_devices('GPU')}")

# ── Reproducibility seed ──
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)
# Out:
# TensorFlow : 2.19.0
# GPUs found : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os

# ── TensorFlow / CUDA log suppression ──
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'   # 0=all, 1=INFO, 2=WARNING, 3=ERROR
os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/usr/local/cuda'

# Optional: silence cuDNN / cuBLAS verbosity
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
tf.get_logger().setLevel('ERROR')

# %%
# ============================================================
# CELL 2  –  Global constants  (edit only this cell)
# ============================================================

# ── Paths ──
DATA_ROOT  = "/home/sandeshprasai/Projects/Final_Semester_Project/AI_Attendance_System/ai-ml-model/DataSets/processed/ThirdLap/"   # ← adjust if needed
SAVE_DIR   = "../../src/models/ImageNetModel"

os.makedirs(SAVE_DIR , exist_ok = True)

# ── Dataset ──
IMG_SIZE      = 112                  # pixels (square)
NUM_CLASSES   = 540                 # identities
IMGS_PER_ID   = 300                 # balanced
VAL_ID_FRAC   = 0.2                 # 108 IDs for val

# ── Model ──
EMB_DIM       = 512                 # embedding dimension

# ── ArcFace ──
ARC_SCALE     = 64.0                # s
ARC_MARGIN    = 0.35                # m

# ── Training ──
BATCH_SIZE    = 64
EPOCHS        = 35
LR_INIT       = 1e-3
LR_MIN        = 1e-6
WEIGHT_DECAY  = 1e-4
PATIENCE      = 8                  # early-stop patience

print("Constants loaded.")
# Out:
# Constants loaded.

# %%
# ============================================================
# CELL 3  –  Identity-disjoint train / val split
# ============================================================

def scan_dataset(root):
    """Return {identity_name: [abs_path, ...]} from a flat folder-of-folders."""
    identity_dict = {}
    for id_name in sorted(os.listdir(root)):
        id_path = os.path.join(root, id_name)
        if not os.path.isdir(id_path):
            continue
        files = [
            os.path.join(id_path, f)
            for f in os.listdir(id_path)
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ]
        if files:
            identity_dict[id_name] = files
    return identity_dict

# ── Scan ──
id_dict = scan_dataset(DATA_ROOT)
all_ids = sorted(id_dict.keys())
print(f"Total identities found : {len(all_ids)}")
print(f"Example identity       : {all_ids[0]}  ({len(id_dict[all_ids[0]])} images)")

# ── Split identities (80 / 20) ──
train_ids, val_ids = train_test_split(
    all_ids, test_size=VAL_ID_FRAC, random_state=SEED
)

# ── Build label map only over TRAINING identities ──
#    Val identities get their own contiguous labels starting at 0
train_id2label = {name: i for i, name in enumerate(sorted(train_ids))}
val_id2label   = {name: i for i, name in enumerate(sorted(val_ids))}

# ── Flat file + label lists ──
train_files, train_labels = [], []
for name in train_ids:
    for fp in id_dict[name]:
        train_files.append(fp)
        train_labels.append(train_id2label[name])

val_files, val_labels = [], []
for name in val_ids:
    for fp in id_dict[name]:
        val_files.append(fp)
        val_labels.append(val_id2label[name])

print(f"\nTrain identities : {len(train_ids)}   images : {len(train_files)}")
print(f"Val   identities : {len(val_ids)}   images : {len(val_files)}")

# ── Persist label maps (useful for inference later) ──
with open(os.path.join(SAVE_DIR, 'train_id2label.json'), 'w') as f:
    json.dump(train_id2label, f)
with open(os.path.join(SAVE_DIR, 'val_id2label.json'), 'w') as f:
    json.dump(val_id2label, f)
# Out:
# Total identities found : 540
# Example identity       : n000001  (288 images)
#
# Train identities : 432   images : 128934
# Val   identities : 108   images : 32247

# %%
# ============================================================
# CELL 4 – tf.data pipeline with augmentation
# ============================================================

import math
import tensorflow as tf


def load_image(path, label):
    """Read + decode + resize + normalise to [-1, 1]."""
    raw = tf.io.read_file(path)
    img = tf.image.decode_jpeg(raw, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = img / 127.5 - 1.0   # → [-1, 1]
    return img, label


def augment(img, label):
    """
    Training-only augmentations (TF-native, GPU-friendly).
    Applied per-image inside the tf.data graph.
    """

    # --------------------------------------------------------
    # Random horizontal flip
    # --------------------------------------------------------
    img = tf.image.random_flip_left_right(img)

    # --------------------------------------------------------
    # Random rotation (±15°) via projective transform
    # --------------------------------------------------------
    angle = tf.random.uniform([], -15.0, 15.0) * math.pi / 180.0
    cos_a = tf.math.cos(angle)
    sin_a = tf.math.sin(angle)
    cx    = tf.cast(IMG_SIZE, tf.float32) / 2.0               # 56.0
    cy    = cx

    tx = cx - cx * cos_a - cy * sin_a
    ty = cy + cx * sin_a - cy * cos_a

    transform = tf.stack([
        cos_a,  sin_a, tx,
       -sin_a,  cos_a, ty,
        0.0,    0.0
    ])

    img = tf.raw_ops.ImageProjectiveTransformV3(
        images=tf.expand_dims(img, 0),
        transforms=tf.expand_dims(transform, 0),
        output_shape=[IMG_SIZE, IMG_SIZE],
        interpolation="BILINEAR",
        fill_mode="CONSTANT",
        fill_value=0.0
    )[0]

    # --------------------------------------------------------
    # Colour jitter
    # --------------------------------------------------------
    img = img * 0.5 + 0.5                                      # [-1,1] → [0,1]
    img = tf.image.random_brightness(img, max_delta=0.2)
    img = tf.image.random_contrast(img, lower=0.8, upper=1.2)
    img = tf.image.random_saturation(img, lower=0.8, upper=1.2)
    img = img * 2.0 - 1.0  

    # --------------------------------------------------------
    # Random erasing (p = 0.2)
    # --------------------------------------------------------
    def _erase(image):
        h, w = IMG_SIZE, IMG_SIZE
        eh = tf.random.uniform([], 8, 40, dtype=tf.int32)
        ew = tf.random.uniform([], 8, 40, dtype=tf.int32)
        y0 = tf.random.uniform([], 0, h - eh, dtype=tf.int32)
        x0 = tf.random.uniform([], 0, w - ew, dtype=tf.int32)

        pad_top = tf.ones([y0, w, 3], tf.float32)
        pad_mid = tf.concat([
            tf.ones([eh, x0, 3], tf.float32),
            tf.zeros([eh, ew, 3], tf.float32),
            tf.ones([eh, w - x0 - ew, 3], tf.float32)
        ], axis=1)
        pad_bot = tf.ones([h - y0 - eh, w, 3], tf.float32)

        mask = tf.concat([pad_top, pad_mid, pad_bot], axis=0)
        return image * mask

    img = tf.cond(
        tf.random.uniform([]) < 0.2,
        lambda: _erase(img),
        lambda: img
    )

    # --------------------------------------------------------
    # Random grayscale (p = 0.1)
    # --------------------------------------------------------
    def _to_gray(x):
        gray = tf.image.rgb_to_grayscale(x)
        return tf.concat([gray, gray, gray], axis=-1)

    img = tf.cond(
        tf.random.uniform([]) < 0.1,
        lambda: _to_gray(img),
        lambda: img
    )

    # --------------------------------------------------------
    # Final clip
    # --------------------------------------------------------
    img = tf.clip_by_value(img, -1.0, 1.0)
    return img, label


def build_dataset(file_paths, labels, is_train=True, batch=BATCH_SIZE):
    """Compose the full tf.data pipeline."""
    ds = tf.data.Dataset.from_tensor_slices(
        (tf.constant(file_paths), tf.constant(labels, tf.int32))
    )
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)

    if is_train:
        ds = ds.shuffle(8192, seed=SEED)
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(batch).prefetch(tf.data.AUTOTUNE)
    return ds


# ------------------------------------------------------------
# Instantiate datasets
# ------------------------------------------------------------
train_ds = build_dataset(train_files, train_labels, is_train=True)
val_ds   = build_dataset(val_files,   val_labels,   is_train=False)

# ------------------------------------------------------------
# Sanity check
# ------------------------------------------------------------
for batch_imgs, batch_labels in train_ds.take(1):
    print(f"Batch shape : {batch_imgs.shape}")
    print(f"Labels     : {batch_labels.shape}")
    print(f"Pixel range: [{batch_imgs.numpy().min():.2f}, "
          f"{batch_imgs.numpy().max():.2f}]")
# Out:
# Batch shape : (64, 112, 112, 3)
# Labels     : (64,)
# Pixel range: [-1.00, 1.00]

# %%
# ============================================================
# CELL 5  –  IR-ResNet-50 backbone (pretrained ImageNet)
# ============================================================

def build_backbone(input_shape=(IMG_SIZE, IMG_SIZE, 3)):
    """
    Returns a Keras Model:
        input  → [B, 112, 112, 3]
        output → [B, 2048]   (after Global Average Pooling)

    Uses ResNet50 with ImageNet weights as the base.
    The top (classification) layers are removed.
    """
    base = tf.keras.applications.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        pooling=None                              # we add our own GAP
    )
    # Global Average Pooling  →  [B, 2048]
    x = tf.keras.layers.GlobalAveragePooling2D()(base.output)
    backbone = tf.keras.Model(inputs=base.input, outputs=x, name='ir_resnet50')
    return backbone

backbone = build_backbone()
backbone.summary(expand_nested=False)
print(f"\nBackbone output shape : {backbone.output_shape}")   # (None, 2048)
# Out:
# 2026-02-04 09:24:08.915429: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 512.0KiB (rounded to 524288)requested by op StatelessRandomUniformV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2026-02-04 09:24:08.915468: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1058] BFCAllocator dump for GPU_0_bfc
# 2026-02-04 09:24:08.915473: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (256): 	Total Chunks: 288, Chunks in use: 288. 72.0KiB allocated for chunks. 72.0KiB in use in bin. 52.9KiB client-requested in use in bin.
# 2026-02-04 09:24:08.915475: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (512): 	Total Chunks: 202, Chunks in use: 202. 101.0KiB allocated for chunks. 101.0KiB in use in bin. 101.0KiB client-requested in use in bin.
# 2026-02-04 09:24:08.915477: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1024): 	Total Chunks: 361, Chunks in use: 361. 364.8KiB allocated for chunks. 364.8KiB in use in bin. 361.0KiB client-requested in use in bin.
# 2026-02-04 09:24:08.915479: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2048): 	Total Chunks: 321, Chunks in use: 321. 650.2KiB allocated for chunks. 650.2KiB in use in bin. 642.0KiB client-requested in use in bin.
# 2026-02-04 09:24:08.915480: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4096): 	Total Chunks: 140, Chunks in use: 140. 579.2KiB allocated for chunks. 579.2KiB in use in bin. 560.0KiB client-requested in use in bin.
# 2026-02-04 09:24:08.915482: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8192): 	Total Chunks: 120, Chunks in use: 120. 1001.5KiB allocated for chunks. 1001.5KiB in use in bin. 960.0KiB client-requested in use in bin.
# 2026-02-04 09:24:08.915484: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16384): 	Total Chunks: 7, Chunks in use: 6. 125.5KiB allocated for chunks. 107.0KiB in use in bin. 96.0KiB client-requested in use in bin.
# 2026-02-04 09:24:08.915485: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (32768): 	Total Chunks: 5, Chunks in use: 5. 193.5KiB allocated for chunks. 193.5KiB in use in bin. 183.8KiB client-requested in use in bin.
# 2026-02-04 09:24:08.915487: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (65536): 	Total Chunks: 39, Chunks in use: 37. 2.76MiB allocated for chunks. 2.62MiB in use in bin. 2.29MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915488: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (131072): 	Total Chunks: 20, Chunks in use: 19. 2.92MiB allocated for chunks. 2.80MiB in use in bin. 2.59MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915490: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (262144): 	Total Chunks: 41, Chunks in use: 39. 11.58MiB allocated for chunks. 10.85MiB in use in bin. 9.31MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915492: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (524288): 	Total Chunks: 23, Chunks in use: 23. 14.11MiB allocated for chunks. 14.11MiB in use in bin. 12.38MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915494: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1048576): 	Total Chunks: 64, Chunks in use: 64. 71.25MiB allocated for chunks. 71.25MiB in use in bin. 62.14MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915495: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2097152): 	Total Chunks: 39, Chunks in use: 39. 99.52MiB allocated for chunks. 99.52MiB in use in bin. 82.75MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915497: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4194304): 	Total Chunks: 79, Chunks in use: 79. 329.42MiB allocated for chunks. 329.42MiB in use in bin. 307.25MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915498: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8388608): 	Total Chunks: 72, Chunks in use: 72. 704.75MiB allocated for chunks. 704.75MiB in use in bin. 689.25MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915500: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16777216): 	Total Chunks: 24, Chunks in use: 24. 556.65MiB allocated for chunks. 556.65MiB in use in bin. 543.90MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915505: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (33554432): 	Total Chunks: 12, Chunks in use: 12. 588.00MiB allocated for chunks. 588.00MiB in use in bin. 588.00MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915507: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (67108864): 	Total Chunks: 18, Chunks in use: 18. 1.71GiB allocated for chunks. 1.71GiB in use in bin. 1.68GiB client-requested in use in bin.
# 2026-02-04 09:24:08.915509: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (134217728): 	Total Chunks: 1, Chunks in use: 1. 175.63MiB allocated for chunks. 175.63MiB in use in bin. 98.00MiB client-requested in use in bin.
# 2026-02-04 09:24:08.915511: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2026-02-04 09:24:08.915513: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1081] Bin for 512.0KiB was 512.0KiB, Chunk State:
# 2026-02-04 09:24:08.915518: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1094] Next region of size 4518445056
# 2026-02-04 09:24:08.915522: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000000 of size 1280 next 1
# 2026-02-04 09:24:08.915523: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000500 of size 256 next 2
# 2026-02-04 09:24:08.915524: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000600 of size 256 next 3
# 2026-02-04 09:24:08.915524: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000700 of size 256 next 4
# 2026-02-04 09:24:08.915525: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000800 of size 256 next 5
# 2026-02-04 09:24:08.915526: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000900 of size 256 next 6
# 2026-02-04 09:24:08.915527: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000a00 of size 256 next 7
# 2026-02-04 09:24:08.915528: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000b00 of size 256 next 8
# 2026-02-04 09:24:08.915528: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000c00 of size 256 next 9
# 2026-02-04 09:24:08.915529: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000d00 of size 256 next 10
# 2026-02-04 09:24:08.915530: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000e00 of size 256 next 11
# 2026-02-04 09:24:08.915531: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce000f00 of size 256 next 12
# 2026-02-04 09:24:08.915532: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001000 of size 256 next 13
# 2026-02-04 09:24:08.915532: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001100 of size 256 next 14
# 2026-02-04 09:24:08.915533: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001200 of size 256 next 16
# 2026-02-04 09:24:08.915534: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001300 of size 256 next 17
# 2026-02-04 09:24:08.915535: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001400 of size 256 next 15
# 2026-02-04 09:24:08.915535: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001500 of size 256 next 18
# 2026-02-04 09:24:08.915536: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001600 of size 256 next 21
# 2026-02-04 09:24:08.915537: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001700 of size 256 next 22
# 2026-02-04 09:24:08.915538: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001800 of size 256 next 23
# 2026-02-04 09:24:08.915539: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001900 of size 256 next 24
# 2026-02-04 09:24:08.915540: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001a00 of size 256 next 182
# 2026-02-04 09:24:08.915541: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001b00 of size 256 next 183
# 2026-02-04 09:24:08.915542: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce001c00 of size 4096 next 184
# 2026-02-04 09:24:08.915544: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce002c00 of size 4096 next 187
# 2026-02-04 09:24:08.915545: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce003c00 of size 4096 next 185
# 2026-02-04 09:24:08.915546: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce004c00 of size 4096 next 186
# 2026-02-04 09:24:08.915548: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce005c00 of size 4096 next 190
# 2026-02-04 09:24:08.915549: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce006c00 of size 1024 next 192
# 2026-02-04 09:24:08.915550: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce007000 of size 1024 next 193
# 2026-02-04 09:24:08.915552: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce007400 of size 1024 next 191
# 2026-02-04 09:24:08.915553: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce007800 of size 1024 next 196
# 2026-02-04 09:24:08.915554: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce007c00 of size 1024 next 197
# 2026-02-04 09:24:08.915555: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce008000 of size 256 next 198
# 2026-02-04 09:24:08.915556: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce008100 of size 256 next 199
# 2026-02-04 09:24:08.915557: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce008200 of size 1024 next 200
# 2026-02-04 09:24:08.915558: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce008600 of size 1024 next 201
# 2026-02-04 09:24:08.915560: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce008a00 of size 1024 next 202
# 2026-02-04 09:24:08.915561: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce008e00 of size 1024 next 205
# 2026-02-04 09:24:08.915562: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce009200 of size 1024 next 206
# 2026-02-04 09:24:08.915563: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce009600 of size 256 next 207
# 2026-02-04 09:24:08.915564: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce009700 of size 256 next 208
# 2026-02-04 09:24:08.915566: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce009800 of size 4096 next 209
# 2026-02-04 09:24:08.915567: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00a800 of size 4096 next 212
# 2026-02-04 09:24:08.915568: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00b800 of size 4096 next 210
# 2026-02-04 09:24:08.915569: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00c800 of size 4096 next 211
# 2026-02-04 09:24:08.915570: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00d800 of size 1024 next 216
# 2026-02-04 09:24:08.915570: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00dc00 of size 1024 next 217
# 2026-02-04 09:24:08.915571: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00e000 of size 1024 next 218
# 2026-02-04 09:24:08.915572: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00e400 of size 1024 next 215
# 2026-02-04 09:24:08.915573: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00e800 of size 1024 next 220
# 2026-02-04 09:24:08.915574: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00ec00 of size 1024 next 222
# 2026-02-04 09:24:08.915575: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00f000 of size 1024 next 223
# 2026-02-04 09:24:08.915576: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00f400 of size 1024 next 224
# 2026-02-04 09:24:08.915576: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce00f800 of size 6144 next 227
# 2026-02-04 09:24:08.915577: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce011000 of size 4096 next 229
# 2026-02-04 09:24:08.915578: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce012000 of size 6912 next 19
# 2026-02-04 09:24:08.915579: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce013b00 of size 256 next 375
# 2026-02-04 09:24:08.915580: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce013c00 of size 16384 next 376
# 2026-02-04 09:24:08.915581: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce017c00 of size 1024 next 29
# 2026-02-04 09:24:08.915582: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce018000 of size 1024 next 20
# 2026-02-04 09:24:08.915582: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce018400 of size 1024 next 25
# 2026-02-04 09:24:08.915583: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce018800 of size 1024 next 27
# 2026-02-04 09:24:08.915584: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce018c00 of size 1024 next 26
# 2026-02-04 09:24:08.915585: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce019000 of size 1024 next 28
# 2026-02-04 09:24:08.915586: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce019400 of size 2048 next 117
# 2026-02-04 09:24:08.915588: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce019c00 of size 4096 next 204
# 2026-02-04 09:24:08.915589: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01ac00 of size 4096 next 90
# 2026-02-04 09:24:08.915590: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01bc00 of size 4096 next 230
# 2026-02-04 09:24:08.915591: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01cc00 of size 1024 next 203
# 2026-02-04 09:24:08.915591: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01d000 of size 1024 next 231
# 2026-02-04 09:24:08.915592: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01d400 of size 1024 next 234
# 2026-02-04 09:24:08.915593: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01d800 of size 1024 next 235
# 2026-02-04 09:24:08.915594: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01dc00 of size 1536 next 31
# 2026-02-04 09:24:08.915595: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01e200 of size 256 next 32
# 2026-02-04 09:24:08.915596: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01e300 of size 256 next 33
# 2026-02-04 09:24:08.915596: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01e400 of size 256 next 34
# 2026-02-04 09:24:08.915597: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01e500 of size 256 next 36
# 2026-02-04 09:24:08.915598: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01e600 of size 256 next 37
# 2026-02-04 09:24:08.915599: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01e700 of size 256 next 35
# 2026-02-04 09:24:08.915600: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01e800 of size 256 next 38
# 2026-02-04 09:24:08.915601: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01e900 of size 256 next 40
# 2026-02-04 09:24:08.915604: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01ea00 of size 256 next 41
# 2026-02-04 09:24:08.915604: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01eb00 of size 256 next 42
# 2026-02-04 09:24:08.915605: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01ec00 of size 256 next 45
# 2026-02-04 09:24:08.915606: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01ed00 of size 256 next 43
# 2026-02-04 09:24:08.915607: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01ee00 of size 256 next 44
# 2026-02-04 09:24:08.915608: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01ef00 of size 1280 next 50
# 2026-02-04 09:24:08.915609: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01f400 of size 1024 next 51
# 2026-02-04 09:24:08.915609: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01f800 of size 1024 next 49
# 2026-02-04 09:24:08.915610: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce01fc00 of size 1024 next 54
# 2026-02-04 09:24:08.915611: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020000 of size 256 next 48
# 2026-02-04 09:24:08.915612: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020100 of size 256 next 55
# 2026-02-04 09:24:08.915613: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020200 of size 256 next 57
# 2026-02-04 09:24:08.915613: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020300 of size 256 next 58
# 2026-02-04 09:24:08.915614: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020400 of size 256 next 56
# 2026-02-04 09:24:08.915615: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020500 of size 256 next 378
# 2026-02-04 09:24:08.915616: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020600 of size 256 next 61
# 2026-02-04 09:24:08.915617: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020700 of size 256 next 63
# 2026-02-04 09:24:08.915617: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020800 of size 256 next 64
# 2026-02-04 09:24:08.915618: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020900 of size 256 next 65
# 2026-02-04 09:24:08.915619: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020a00 of size 1024 next 68
# 2026-02-04 09:24:08.915620: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce020e00 of size 1024 next 70
# 2026-02-04 09:24:08.915621: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce021200 of size 1024 next 71
# 2026-02-04 09:24:08.915622: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce021600 of size 1024 next 69
# 2026-02-04 09:24:08.915622: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce021a00 of size 1024 next 72
# 2026-02-04 09:24:08.915623: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce021e00 of size 256 next 62
# 2026-02-04 09:24:08.915624: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce021f00 of size 256 next 73
# 2026-02-04 09:24:08.915625: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022000 of size 256 next 75
# 2026-02-04 09:24:08.915626: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022100 of size 256 next 76
# 2026-02-04 09:24:08.915627: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022200 of size 256 next 74
# 2026-02-04 09:24:08.915628: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022300 of size 256 next 78
# 2026-02-04 09:24:08.915629: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022400 of size 256 next 79
# 2026-02-04 09:24:08.915629: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022500 of size 256 next 81
# 2026-02-04 09:24:08.915630: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022600 of size 256 next 82
# 2026-02-04 09:24:08.915631: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022700 of size 256 next 80
# 2026-02-04 09:24:08.915632: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022800 of size 1024 next 86
# 2026-02-04 09:24:08.915633: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce022c00 of size 1024 next 88
# 2026-02-04 09:24:08.915634: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce023000 of size 1024 next 89
# 2026-02-04 09:24:08.915634: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce023400 of size 1024 next 87
# 2026-02-04 09:24:08.915635: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce023800 of size 1024 next 91
# 2026-02-04 09:24:08.915636: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce023c00 of size 512 next 85
# 2026-02-04 09:24:08.915637: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce023e00 of size 512 next 92
# 2026-02-04 09:24:08.915638: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce024000 of size 256 next 93
# 2026-02-04 09:24:08.915638: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce024100 of size 256 next 94
# 2026-02-04 09:24:08.915639: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce024200 of size 2048 next 95
# 2026-02-04 09:24:08.915640: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce024a00 of size 2048 next 98
# 2026-02-04 09:24:08.915641: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce025200 of size 2048 next 96
# 2026-02-04 09:24:08.915642: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce025a00 of size 3584 next 39
# 2026-02-04 09:24:08.915643: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce026800 of size 91904 next 30
# 2026-02-04 09:24:08.915644: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03cf00 of size 2048 next 97
# 2026-02-04 09:24:08.915645: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03d700 of size 256 next 101
# 2026-02-04 09:24:08.915645: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03d800 of size 256 next 102
# 2026-02-04 09:24:08.915646: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03d900 of size 512 next 103
# 2026-02-04 09:24:08.915647: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03db00 of size 512 next 104
# 2026-02-04 09:24:08.915648: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03dd00 of size 512 next 105
# 2026-02-04 09:24:08.915648: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03df00 of size 512 next 116
# 2026-02-04 09:24:08.915649: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03e100 of size 512 next 109
# 2026-02-04 09:24:08.915650: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03e300 of size 256 next 110
# 2026-02-04 09:24:08.915651: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03e400 of size 256 next 111
# 2026-02-04 09:24:08.915652: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03e500 of size 512 next 112
# 2026-02-04 09:24:08.915653: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03e700 of size 512 next 113
# 2026-02-04 09:24:08.915654: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03e900 of size 512 next 114
# 2026-02-04 09:24:08.915655: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03eb00 of size 512 next 99
# 2026-02-04 09:24:08.915655: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03ed00 of size 512 next 118
# 2026-02-04 09:24:08.915656: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03ef00 of size 256 next 119
# 2026-02-04 09:24:08.915657: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03f000 of size 256 next 120
# 2026-02-04 09:24:08.915658: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03f100 of size 2048 next 121
# 2026-02-04 09:24:08.915659: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce03f900 of size 2048 next 124
# 2026-02-04 09:24:08.915659: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce040100 of size 2048 next 122
# 2026-02-04 09:24:08.915660: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce040900 of size 2048 next 123
# 2026-02-04 09:24:08.915661: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce041100 of size 512 next 128
# 2026-02-04 09:24:08.915662: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce041300 of size 512 next 129
# 2026-02-04 09:24:08.915663: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce041500 of size 512 next 130
# 2026-02-04 09:24:08.915663: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce041700 of size 512 next 127
# 2026-02-04 09:24:08.915664: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce041900 of size 512 next 132
# 2026-02-04 09:24:08.915665: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce041b00 of size 512 next 134
# 2026-02-04 09:24:08.915666: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce041d00 of size 512 next 135
# 2026-02-04 09:24:08.915667: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce041f00 of size 512 next 136
# 2026-02-04 09:24:08.915668: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce042100 of size 3072 next 139
# 2026-02-04 09:24:08.915669: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce042d00 of size 2048 next 141
# 2026-02-04 09:24:08.915669: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce043500 of size 2048 next 142
# 2026-02-04 09:24:08.915670: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce043d00 of size 2048 next 140
# 2026-02-04 09:24:08.915671: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce044500 of size 2048 next 143
# 2026-02-04 09:24:08.915672: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce044d00 of size 512 next 100
# 2026-02-04 09:24:08.915673: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce044f00 of size 512 next 145
# 2026-02-04 09:24:08.915673: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce045100 of size 512 next 147
# 2026-02-04 09:24:08.915674: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce045300 of size 512 next 148
# 2026-02-04 09:24:08.915675: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce045500 of size 512 next 146
# 2026-02-04 09:24:08.915676: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce045700 of size 512 next 150
# 2026-02-04 09:24:08.915677: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce045900 of size 512 next 151
# 2026-02-04 09:24:08.915678: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce045b00 of size 512 next 153
# 2026-02-04 09:24:08.915679: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce045d00 of size 512 next 154
# 2026-02-04 09:24:08.915680: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce045f00 of size 512 next 152
# 2026-02-04 09:24:08.915681: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce046100 of size 2048 next 158
# 2026-02-04 09:24:08.915682: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce046900 of size 2048 next 160
# 2026-02-04 09:24:08.915682: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce047100 of size 2048 next 161
# 2026-02-04 09:24:08.915683: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce047900 of size 2048 next 159
# 2026-02-04 09:24:08.915684: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce048100 of size 2048 next 163
# 2026-02-04 09:24:08.915685: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce048900 of size 512 next 156
# 2026-02-04 09:24:08.915686: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce048b00 of size 512 next 164
# 2026-02-04 09:24:08.915687: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce048d00 of size 512 next 166
# 2026-02-04 09:24:08.915687: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce048f00 of size 512 next 167
# 2026-02-04 09:24:08.915688: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce049100 of size 512 next 165
# 2026-02-04 09:24:08.915689: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce049300 of size 512 next 168
# 2026-02-04 09:24:08.915690: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce049500 of size 512 next 169
# 2026-02-04 09:24:08.915691: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce049700 of size 512 next 171
# 2026-02-04 09:24:08.915692: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce049900 of size 512 next 172
# 2026-02-04 09:24:08.915692: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce049b00 of size 512 next 170
# 2026-02-04 09:24:08.915693: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce049d00 of size 2048 next 176
# 2026-02-04 09:24:08.915694: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce04a500 of size 2048 next 178
# 2026-02-04 09:24:08.915695: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce04ad00 of size 2048 next 179
# 2026-02-04 09:24:08.915696: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce04b500 of size 2048 next 177
# 2026-02-04 09:24:08.915696: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce04bd00 of size 2048 next 181
# 2026-02-04 09:24:08.915697: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce04c500 of size 1024 next 126
# 2026-02-04 09:24:08.915698: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce04c900 of size 1536 next 53
# 2026-02-04 09:24:08.915699: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce04cf00 of size 65536 next 52
# 2026-02-04 09:24:08.915700: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce05cf00 of size 65536 next 59
# 2026-02-04 09:24:08.915701: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce06cf00 of size 8192 next 424
# 2026-02-04 09:24:08.915702: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce06ef00 of size 8192 next 425
# 2026-02-04 09:24:08.915703: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce070f00 of size 2048 next 431
# 2026-02-04 09:24:08.915704: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce071700 of size 2048 next 432
# 2026-02-04 09:24:08.915705: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce071f00 of size 8192 next 435
# 2026-02-04 09:24:08.915706: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce073f00 of size 8192 next 436
# 2026-02-04 09:24:08.915706: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce075f00 of size 256 next 390
# 2026-02-04 09:24:08.915707: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce076000 of size 256 next 442
# 2026-02-04 09:24:08.915708: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce076100 of size 256 next 391
# 2026-02-04 09:24:08.915709: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce076200 of size 1024 next 445
# 2026-02-04 09:24:08.915710: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce076600 of size 1024 next 388
# 2026-02-04 09:24:08.915711: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce076a00 of size 1280 next 444
# 2026-02-04 09:24:08.915712: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce076f00 of size 2048 next 448
# 2026-02-04 09:24:08.915712: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce077700 of size 2048 next 449
# 2026-02-04 09:24:08.915713: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce077f00 of size 2048 next 452
# 2026-02-04 09:24:08.915714: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce078700 of size 2048 next 453
# 2026-02-04 09:24:08.915715: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce078f00 of size 8192 next 456
# 2026-02-04 09:24:08.915716: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce07af00 of size 8192 next 457
# 2026-02-04 09:24:08.915717: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce07cf00 of size 8192 next 460
# 2026-02-04 09:24:08.915718: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce07ef00 of size 8192 next 461
# 2026-02-04 09:24:08.915719: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce080f00 of size 2048 next 464
# 2026-02-04 09:24:08.915719: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce081700 of size 2048 next 465
# 2026-02-04 09:24:08.915720: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce081f00 of size 2048 next 468
# 2026-02-04 09:24:08.915721: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce082700 of size 2048 next 469
# 2026-02-04 09:24:08.915722: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce082f00 of size 8192 next 47
# 2026-02-04 09:24:08.915723: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce084f00 of size 65536 next 377
# 2026-02-04 09:24:08.915724: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce094f00 of size 81920 next 46
# 2026-02-04 09:24:08.915727: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0a8f00 of size 65536 next 77
# 2026-02-04 09:24:08.915729: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0b8f00 of size 8192 next 332
# 2026-02-04 09:24:08.915730: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0baf00 of size 8192 next 335
# 2026-02-04 09:24:08.915730: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0bcf00 of size 8192 next 333
# 2026-02-04 09:24:08.915731: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0bef00 of size 2048 next 338
# 2026-02-04 09:24:08.915732: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0bf700 of size 2048 next 339
# 2026-02-04 09:24:08.915733: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0bff00 of size 2048 next 340
# 2026-02-04 09:24:08.915734: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c0700 of size 2048 next 348
# 2026-02-04 09:24:08.915735: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c0f00 of size 2048 next 342
# 2026-02-04 09:24:08.915736: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c1700 of size 2048 next 344
# 2026-02-04 09:24:08.915736: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c1f00 of size 2048 next 345
# 2026-02-04 09:24:08.915737: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c2700 of size 2048 next 346
# 2026-02-04 09:24:08.915738: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c2f00 of size 12288 next 349
# 2026-02-04 09:24:08.915739: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c5f00 of size 8192 next 351
# 2026-02-04 09:24:08.915740: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c7f00 of size 8192 next 352
# 2026-02-04 09:24:08.915741: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0c9f00 of size 8192 next 350
# 2026-02-04 09:24:08.915742: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0cbf00 of size 8192 next 353
# 2026-02-04 09:24:08.915743: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0cdf00 of size 2048 next 337
# 2026-02-04 09:24:08.915744: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0ce700 of size 2048 next 355
# 2026-02-04 09:24:08.915744: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0cef00 of size 2048 next 357
# 2026-02-04 09:24:08.915745: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0cf700 of size 2048 next 358
# 2026-02-04 09:24:08.915746: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0cff00 of size 2048 next 356
# 2026-02-04 09:24:08.915747: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d0700 of size 2048 next 365
# 2026-02-04 09:24:08.915748: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d0f00 of size 2048 next 361
# 2026-02-04 09:24:08.915749: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d1700 of size 2048 next 363
# 2026-02-04 09:24:08.915749: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d1f00 of size 2048 next 364
# 2026-02-04 09:24:08.915750: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d2700 of size 2048 next 362
# 2026-02-04 09:24:08.915751: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d2f00 of size 8192 next 368
# 2026-02-04 09:24:08.915752: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d4f00 of size 8192 next 370
# 2026-02-04 09:24:08.915753: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d6f00 of size 8192 next 371
# 2026-02-04 09:24:08.915754: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0d8f00 of size 8192 next 369
# 2026-02-04 09:24:08.915755: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0daf00 of size 8192 next 373
# 2026-02-04 09:24:08.915756: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0dcf00 of size 2048 next 367
# 2026-02-04 09:24:08.915757: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0dd700 of size 2048 next 334
# 2026-02-04 09:24:08.915759: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0ddf00 of size 2048 next 317
# 2026-02-04 09:24:08.915760: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0de700 of size 2048 next 374
# 2026-02-04 09:24:08.915762: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0def00 of size 73728 next 67
# 2026-02-04 09:24:08.915763: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce0f0f00 of size 147456 next 66
# 2026-02-04 09:24:08.915764: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce114f00 of size 1024 next 233
# 2026-02-04 09:24:08.915765: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce115300 of size 1024 next 238
# 2026-02-04 09:24:08.915766: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce115700 of size 1024 next 240
# 2026-02-04 09:24:08.915767: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce115b00 of size 1024 next 241
# 2026-02-04 09:24:08.915768: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce115f00 of size 1024 next 239
# 2026-02-04 09:24:08.915769: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce116300 of size 4096 next 228
# 2026-02-04 09:24:08.915769: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce117300 of size 4096 next 245
# 2026-02-04 09:24:08.915770: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce118300 of size 4096 next 247
# 2026-02-04 09:24:08.915771: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce119300 of size 4096 next 248
# 2026-02-04 09:24:08.915772: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11a300 of size 4096 next 246
# 2026-02-04 09:24:08.915773: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11b300 of size 1024 next 250
# 2026-02-04 09:24:08.915774: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11b700 of size 1024 next 251
# 2026-02-04 09:24:08.915775: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11bb00 of size 1024 next 253
# 2026-02-04 09:24:08.915775: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11bf00 of size 1024 next 254
# 2026-02-04 09:24:08.915776: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11c300 of size 1024 next 252
# 2026-02-04 09:24:08.915777: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11c700 of size 1024 next 255
# 2026-02-04 09:24:08.915778: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11cb00 of size 1024 next 256
# 2026-02-04 09:24:08.915779: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11cf00 of size 1024 next 258
# 2026-02-04 09:24:08.915780: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11d300 of size 1024 next 259
# 2026-02-04 09:24:08.915780: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11d700 of size 1024 next 257
# 2026-02-04 09:24:08.915781: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11db00 of size 4096 next 242
# 2026-02-04 09:24:08.915782: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11eb00 of size 4096 next 263
# 2026-02-04 09:24:08.915783: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce11fb00 of size 4096 next 265
# 2026-02-04 09:24:08.915784: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce120b00 of size 4096 next 266
# 2026-02-04 09:24:08.915785: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce121b00 of size 4096 next 264
# 2026-02-04 09:24:08.915786: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce122b00 of size 1024 next 267
# 2026-02-04 09:24:08.915787: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce122f00 of size 1024 next 269
# 2026-02-04 09:24:08.915788: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce123300 of size 1024 next 271
# 2026-02-04 09:24:08.915789: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce123700 of size 1024 next 272
# 2026-02-04 09:24:08.915789: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce123b00 of size 1024 next 270
# 2026-02-04 09:24:08.915790: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce123f00 of size 1024 next 261
# 2026-02-04 09:24:08.915791: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce124300 of size 1024 next 274
# 2026-02-04 09:24:08.915792: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce124700 of size 1024 next 276
# 2026-02-04 09:24:08.915793: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce124b00 of size 1024 next 277
# 2026-02-04 09:24:08.915794: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce124f00 of size 4096 next 260
# 2026-02-04 09:24:08.915794: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce125f00 of size 8192 next 328
# 2026-02-04 09:24:08.915795: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce127f00 of size 256 next 347
# 2026-02-04 09:24:08.915796: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128000 of size 256 next 189
# 2026-02-04 09:24:08.915797: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128100 of size 256 next 188
# 2026-02-04 09:24:08.915798: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128200 of size 256 next 219
# 2026-02-04 09:24:08.915799: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128300 of size 256 next 194
# 2026-02-04 09:24:08.915800: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128400 of size 256 next 106
# 2026-02-04 09:24:08.915800: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128500 of size 256 next 108
# 2026-02-04 09:24:08.915801: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128600 of size 256 next 379
# 2026-02-04 09:24:08.915802: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128700 of size 256 next 380
# 2026-02-04 09:24:08.915803: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128800 of size 256 next 1279
# 2026-02-04 09:24:08.915804: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128900 of size 256 next 384
# 2026-02-04 09:24:08.915805: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128a00 of size 256 next 385
# 2026-02-04 09:24:08.915806: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128b00 of size 256 next 386
# 2026-02-04 09:24:08.915806: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128c00 of size 256 next 387
# 2026-02-04 09:24:08.915807: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128d00 of size 256 next 1599
# 2026-02-04 09:24:08.915808: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 77d0ce128e00 of size 256 next 392
# ...
# 2026-02-04 09:24:08.933593: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 73728 totalling 72.0KiB
# 2026-02-04 09:24:08.933594: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 81920 totalling 320.0KiB
# 2026-02-04 09:24:08.933595: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 83712 totalling 81.8KiB
# 2026-02-04 09:24:08.933596: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 89344 totalling 87.2KiB
# 2026-02-04 09:24:08.933597: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 91904 totalling 89.8KiB
# 2026-02-04 09:24:08.933598: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 98304 totalling 96.0KiB
# 2026-02-04 09:24:08.933600: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 104448 totalling 102.0KiB
# 2026-02-04 09:24:08.933601: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 114688 totalling 112.0KiB
# 2026-02-04 09:24:08.933603: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 124416 totalling 121.5KiB
# 2026-02-04 09:24:08.933605: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 131072 totalling 128.0KiB
# 2026-02-04 09:24:08.933607: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 14 Chunks of size 147456 totalling 1.97MiB
# 2026-02-04 09:24:08.933608: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 163840 totalling 160.0KiB
# 2026-02-04 09:24:08.933609: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 180224 totalling 352.0KiB
# 2026-02-04 09:24:08.933610: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 212992 totalling 208.0KiB
# 2026-02-04 09:24:08.933611: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 27 Chunks of size 262144 totalling 6.75MiB
# 2026-02-04 09:24:08.933612: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 281856 totalling 275.2KiB
# 2026-02-04 09:24:08.933614: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 6 Chunks of size 327680 totalling 1.88MiB
# 2026-02-04 09:24:08.933615: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 376832 totalling 368.0KiB
# 2026-02-04 09:24:08.933616: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 393216 totalling 768.0KiB
# 2026-02-04 09:24:08.933617: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 434176 totalling 424.0KiB
# 2026-02-04 09:24:08.933618: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 450560 totalling 440.0KiB
# 2026-02-04 09:24:08.933619: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 6 Chunks of size 524288 totalling 3.00MiB
# 2026-02-04 09:24:08.933620: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 10 Chunks of size 589824 totalling 5.62MiB
# 2026-02-04 09:24:08.933622: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 655360 totalling 1.25MiB
# 2026-02-04 09:24:08.933623: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 770048 totalling 752.0KiB
# 2026-02-04 09:24:08.933624: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 917504 totalling 3.50MiB
# 2026-02-04 09:24:08.933625: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 31 Chunks of size 1048576 totalling 31.00MiB
# 2026-02-04 09:24:08.933626: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 1097728 totalling 1.05MiB
# 2026-02-04 09:24:08.933627: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 10 Chunks of size 1105920 totalling 10.55MiB
# 2026-02-04 09:24:08.933628: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 1130496 totalling 1.08MiB
# 2026-02-04 09:24:08.933629: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 1187840 totalling 1.13MiB
# 2026-02-04 09:24:08.933631: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 15 Chunks of size 1310720 totalling 18.75MiB
# 2026-02-04 09:24:08.933632: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 1368064 totalling 1.30MiB
# 2026-02-04 09:24:08.933633: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 3 Chunks of size 1572864 totalling 4.50MiB
# 2026-02-04 09:24:08.933634: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 1982464 totalling 1.89MiB
# 2026-02-04 09:24:08.933635: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 13 Chunks of size 2097152 totalling 26.00MiB
# 2026-02-04 09:24:08.933636: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 10 Chunks of size 2359296 totalling 22.50MiB
# 2026-02-04 09:24:08.933637: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 2621440 totalling 2.50MiB
# 2026-02-04 09:24:08.933639: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 2752512 totalling 5.25MiB
# 2026-02-04 09:24:08.933641: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 2883584 totalling 11.00MiB
# 2026-02-04 09:24:08.933643: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 7 Chunks of size 3670016 totalling 24.50MiB
# 2026-02-04 09:24:08.933645: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 4063232 totalling 3.88MiB
# 2026-02-04 09:24:08.933646: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 4079616 totalling 3.89MiB
# 2026-02-04 09:24:08.933647: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 68 Chunks of size 4194304 totalling 272.00MiB
# 2026-02-04 09:24:08.933648: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 4367872 totalling 4.17MiB
# 2026-02-04 09:24:08.933649: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 4456448 totalling 4.25MiB
# 2026-02-04 09:24:08.933650: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 4718592 totalling 4.50MiB
# 2026-02-04 09:24:08.933652: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 5242880 totalling 20.00MiB
# 2026-02-04 09:24:08.933653: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 5767168 totalling 5.50MiB
# 2026-02-04 09:24:08.933654: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 6291456 totalling 12.00MiB
# 2026-02-04 09:24:08.933655: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 7340032 totalling 7.00MiB
# 2026-02-04 09:24:08.933656: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 10 Chunks of size 8388608 totalling 80.00MiB
# 2026-02-04 09:24:08.933657: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 8912896 totalling 8.50MiB
# 2026-02-04 09:24:08.933658: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 40 Chunks of size 9437184 totalling 360.00MiB
# 2026-02-04 09:24:08.933659: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 10485760 totalling 10.00MiB
# 2026-02-04 09:24:08.933661: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 12582912 totalling 24.00MiB
# 2026-02-04 09:24:08.933662: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 17 Chunks of size 12845056 totalling 208.25MiB
# 2026-02-04 09:24:08.933663: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 14680064 totalling 14.00MiB
# 2026-02-04 09:24:08.933664: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 16777216 totalling 16.00MiB
# 2026-02-04 09:24:08.933665: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 18874368 totalling 18.00MiB
# 2026-02-04 09:24:08.933666: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 19267584 totalling 36.75MiB
# 2026-02-04 09:24:08.933668: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 21387264 totalling 20.40MiB
# 2026-02-04 09:24:08.933669: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 19 Chunks of size 25690112 totalling 465.50MiB
# 2026-02-04 09:24:08.933670: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 12 Chunks of size 51380224 totalling 588.00MiB
# 2026-02-04 09:24:08.933671: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 80117504 totalling 76.41MiB
# 2026-02-04 09:24:08.933672: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 16 Chunks of size 102760448 totalling 1.53GiB
# 2026-02-04 09:24:08.933674: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 110231552 totalling 105.12MiB
# 2026-02-04 09:24:08.933676: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 184159744 totalling 175.63MiB
# 2026-02-04 09:24:08.933678: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1126] Sum Total of in-use chunks: 4.21GiB
# 2026-02-04 09:24:08.933681: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1128] Total bytes in pool: 4518445056 memory_limit_: 4518445056 available bytes: 0 curr_region_allocation_bytes_: 9036890112
# 2026-02-04 09:24:08.933685: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1133] Stats:
# Limit:                      4518445056
# InUse:                      4517377536
# MaxInUse:                   4517764352
# NumAllocs:                       49713
# MaxAllocSize:               2449473536
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2026-02-04 09:24:08.933707: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] ****************************x***********************************************************************
# 2026-02-04 09:24:08.933727: W tensorflow/core/framework/op_kernel.cc:1857] OP_REQUIRES failed at stateless_random_ops_v2.cc:64 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1,1,256,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[58], line 25
#      22     backbone = tf.keras.Model(inputs=base.input, outputs=x, name='ir_resnet50')
#      23     return backbone
# ---> 25 backbone = build_backbone()
#      26 backbone.summary(expand_nested=False)
#      27 print(f"\nBackbone output shape : {backbone.output_shape}")   # (None, 2048)
#
# Cell In[58], line 14, in build_backbone(input_shape)
#       5 def build_backbone(input_shape=(IMG_SIZE, IMG_SIZE, 3)):
#       6     """
#       7     Returns a Keras Model:
#       8         input  → [B, 112, 112, 3]
#    (...)
#      12     The top (classification) layers are removed.
#      13     """
# ---> 14     base = tf.keras.applications.ResNet50(
#      15         include_top=False,
#      16         weights='imagenet',
#      17         input_shape=input_shape,
#      18         pooling=None                              # we add our own GAP
#      19     )
#      20     # Global Average Pooling  →  [B, 2048]
#      21     x = tf.keras.layers.GlobalAveragePooling2D()(base.output)
#
# File ~/Projects/Final_Semester_Project/AI_Attendance_System/ai-ml-model/FaceEnv/lib/python3.10/site-packages/keras/src/applications/resnet.py:409, in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation, name)
#     406     x = stack_residual_blocks_v1(x, 256, 6, name="conv4")
#     407     return stack_residual_blocks_v1(x, 512, 3, name="conv5")
# --> 409 return ResNet(
#     410     stack_fn,
#     411     preact=False,
#     412     use_bias=True,
#     413     weights_name="resnet50",
#     414     name=name,
#     415     include_top=include_top,
#     416     weights=weights,
#     417     input_tensor=input_tensor,
#     418     input_shape=input_shape,
#     419     pooling=pooling,
#     420     classes=classes,
#     421     classifier_activation=classifier_activation,
#     422 )
#
# File ~/Projects/Final_Semester_Project/AI_Attendance_System/ai-ml-model/FaceEnv/lib/python3.10/site-packages/keras/src/applications/resnet.py:163, in ResNet(stack_fn, preact, use_bias, include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation, name, weights_name)
#     160 x = layers.ZeroPadding2D(padding=((1, 1), (1, 1)), name="pool1_pad")(x)
#     161 x = layers.MaxPooling2D(3, strides=2, name="pool1_pool")(x)
# --> 163 x = stack_fn(x)
#     165 if preact:
#     166     x = layers.BatchNormalization(
#     167         axis=bn_axis, epsilon=1.001e-5, name="post_bn"
#     168     )(x)
#
# File ~/Projects/Final_Semester_Project/AI_Attendance_System/ai-ml-model/FaceEnv/lib/python3.10/site-packages/keras/src/applications/resnet.py:405, in ResNet50.<locals>.stack_fn(x)
#     403 def stack_fn(x):
#     404     x = stack_residual_blocks_v1(x, 64, 3, stride1=1, name="conv2")
# --> 405     x = stack_residual_blocks_v1(x, 128, 4, name="conv3")
#     406     x = stack_residual_blocks_v1(x, 256, 6, name="conv4")
#     407     return stack_residual_blocks_v1(x, 512, 3, name="conv5")
#
# File ~/Projects/Final_Semester_Project/AI_Attendance_System/ai-ml-model/FaceEnv/lib/python3.10/site-packages/keras/src/applications/resnet.py:290, in stack_residual_blocks_v1(x, filters, blocks, stride1, name)
#     276 def stack_residual_blocks_v1(x, filters, blocks, stride1=2, name=None):
#     277     """A set of stacked residual blocks.
#     278
#     279     Args:
#    (...)
#     287         Output tensor for the stacked blocks.
#     288     """
# --> 290     x = residual_block_v1(x, filters, stride=stride1, name=f"{name}_block1")
#     291     for i in range(2, blocks + 1):
#     292         x = residual_block_v1(
#     293             x, filters, conv_shortcut=False, name=f"{name}_block{i}"
#     294         )
#
# File ~/Projects/Final_Semester_Project/AI_Attendance_System/ai-ml-model/FaceEnv/lib/python3.10/site-packages/keras/src/applications/resnet.py:243, in residual_block_v1(x, filters, kernel_size, stride, conv_shortcut, name)
#     240     bn_axis = 1
#     242 if conv_shortcut:
# --> 243     shortcut = layers.Conv2D(
#     244         4 * filters, 1, strides=stride, name=f"{name}_0_conv"
#     245     )(x)
#     246     shortcut = layers.BatchNormalization(
#     247         axis=bn_axis, epsilon=1.001e-5, name=f"{name}_0_bn"
#     248     )(shortcut)
#     249 else:
#
# File ~/Projects/Final_Semester_Project/AI_Attendance_System/ai-ml-model/FaceEnv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Projects/Final_Semester_Project/AI_Attendance_System/ai-ml-model/FaceEnv/lib/python3.10/site-packages/keras/src/backend/tensorflow/random.py:34, in uniform(shape, minval, maxval, dtype, seed)
#      32 dtype = dtype or floatx()
#      33 seed = _cast_seed(draw_seed(seed))
# ---> 34 return tf.random.stateless_uniform(
#      35     shape=shape,
#      36     minval=tf.cast(minval, dtype),
#      37     maxval=tf.cast(maxval, dtype),
#      38     dtype=dtype,
#      39     seed=seed,
#      40 )
#
# ResourceExhaustedError: {{function_node __wrapped__StatelessRandomUniformV2_device_/job:localhost/replica:0/task:0/device:GPU:0}} OOM when allocating tensor with shape[1,1,256,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:StatelessRandomUniformV2] name:

# %%
# ============================================================
# CELL 6  –  Embedding head  (Dense → BN → L2 Normalise)
# ============================================================

class L2Normalize(tf.keras.layers.Layer):
    """Custom layer: L2-normalises along the last axis."""
    def call(self, x):
        return tf.nn.l2_normalize(x, axis=-1)


def build_embedding_model():
    """
    Full feature-extractor:
        input  → [B, 112, 112, 3]
        output → [B, 512]  (unit-normalised embedding)
    """
    inp = tf.keras.layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name='face_input')

    x = backbone(inp)                                  # [B, 2048]
    x = tf.keras.layers.Dense(EMB_DIM, use_bias=False, name='fc_embed')(x)
    x = tf.keras.layers.BatchNormalization(name='bn_embed')(x)
    x = L2Normalize(name='l2_norm')(x)                       # unit hypersphere

    emb_model = tf.keras.Model(inputs=inp, outputs=x, name='face_embedding')
    return emb_model

embedding_model = build_embedding_model()
embedding_model.summary()
print(f"\nEmbedding output shape : {embedding_model.output_shape}")  # (None, 512)

# %%
# ============================================================
# CELL 7  –  ArcFace loss  (custom Keras layer)
# ============================================================

class ArcFaceLayer(tf.keras.layers.Layer):
    """
    Additive-Angular-Margin Softmax (ArcFace).

    Args
    ----
    num_classes : int   number of training identities
    emb_dim     : int   embedding dimension (512)
    scale       : float s – logit scale
    margin      : float m – angular margin (radians concept, passed as float)
    """
    def __init__(self, num_classes, emb_dim, scale=64.0, margin=0.5, **kwargs):
        super().__init__(**kwargs)
        self.num_classes = num_classes
        self.emb_dim     = emb_dim
        self.s           = scale
        self.m           = margin
        self.cos_m       = tf.constant(math.cos(margin), dtype=tf.float32)
        self.sin_m       = tf.constant(math.sin(margin), dtype=tf.float32)
        self.th          = tf.constant(math.cos(math.pi - margin), dtype=tf.float32)
        self.mm          = tf.constant(math.sin(math.pi - margin) * margin, dtype=tf.float32)

    def build(self, input_shape):
        self.W = self.add_weight(
            name='arcface_W',
            shape=(self.num_classes, self.emb_dim),
            initializer='glorot_uniform',
            trainable=True
        )
        super().build(input_shape)

    def call(self, inputs):
        """
        inputs: tuple  (embeddings [B, D],  labels [B, 1])
        returns: logits [B, num_classes]  → feed to SparseCategoricalCE
        """
        emb, labels = inputs

        # labels arrive as [B, 1] from the Input layer;
        # tf.one_hot needs [B] so squeeze the trailing dim
        labels = tf.squeeze(labels, axis=-1)                # [B, 1] → [B]

        # normalise class weights  →  unit vectors
        W_norm = tf.nn.l2_normalize(self.W, axis=1)         # [C, D]

        # cosine similarity matrix
        cosine = tf.matmul(emb, W_norm, transpose_b=True)   # [B, C]
        sine   = tf.sqrt(tf.clip_by_value(1.0 - cosine**2, 1e-8, 1.0))

        # cos(θ + m) = cos θ · cos m  −  sin θ · sin m
        phi = cosine * self.cos_m - sine * self.sin_m

        # easy-margin: guard when cos θ < th  (i.e. θ + m > π)
        phi = tf.where(cosine > self.th, phi, cosine - self.mm)

        # one-hot: replace target column with margin-adjusted logit
        one_hot = tf.one_hot(tf.cast(labels, tf.int32), self.num_classes)   # [B, C]
        output  = one_hot * phi + (1.0 - one_hot) * cosine
        output  = output * self.s                            # scale
        return output

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            'num_classes': self.num_classes, 'emb_dim': self.emb_dim,
            'scale': self.s, 'margin': self.m
        })
        return cfg

print("ArcFaceLayer defined.")

# %%
# ============================================================
# CELL 8  –  Full training model  (embedding + ArcFace head)
# ============================================================

def build_training_model(num_classes):
    """
    Inputs  : face_input  [B, 112, 112, 3]
              label_input [B, 1]
    Output  : logits      [B, num_classes]

    At inference time use `embedding_model` directly.
    """
    face_input  = tf.keras.layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name='face_input')
    label_input = tf.keras.layers.Input(shape=(1,), dtype=tf.int32, name='label_input')

    emb    = embedding_model(face_input)                 # [B, 512]
    logits = ArcFaceLayer(
        num_classes=num_classes,
        emb_dim=EMB_DIM,
        scale=ARC_SCALE,
        margin=ARC_MARGIN,
        name='arcface'
    )([emb, label_input])                                # [B, C]

    train_model = tf.keras.Model(
        inputs=[face_input, label_input],
        outputs=logits,
        name='arcface_training'
    )
    return train_model

train_model = build_training_model(NUM_CLASSES)
train_model.summary(expand_nested=False)

# ── Freeze backbone initially (2 epochs warm-up) ──
embedding_model.trainable = False
print("\nBackbone frozen for warm-up. Will unfreeze after epoch 2.")

# %%
# ============================================================
# CELL 9  –  Custom training loop with warm-up unfreeze
# ============================================================
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tqdm import tqdm
import time

WARMUP_EPOCHS = 2  # freeze backbone for this many epochs

# ── Loss ──
loss_fn = SparseCategoricalCrossentropy(from_logits=True)

# ── Initial optimiser (head only) ──
optimiser = AdamW(learning_rate=LR_INIT, weight_decay=WEIGHT_DECAY)
train_model.compile(optimizer=optimiser, loss=loss_fn)

# ── LR schedule: cosine decay ──
steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()
cosine_sched = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=LR_INIT,
    decay_steps=EPOCHS * steps_per_epoch,
    alpha=LR_MIN / LR_INIT
)

# ── History storage ──
history = {'train_loss': [], 'val_loss': [], 'val_auc': [], 'lr': []}
best_auc = 0.0
patience_counter = 0

# ─── helper: run one epoch ───
def run_epoch(epoch_idx):
    global best_auc, patience_counter

    epoch_start = time.time()

    # ── Warm-up unfreeze logic ──
    if epoch_idx == WARMUP_EPOCHS:
        print("→ Unfreezing LAST ResNet block only & freezing BN …")

    for layer in backbone.layers:
        layer.trainable = layer.name.startswith("conv5")

    for layer in backbone.layers:
        if isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = False

    # ── Recompile with cosine LR ──
    train_model.compile(
        optimizer=AdamW(
            learning_rate=cosine_sched,
            weight_decay=WEIGHT_DECAY
        ),
        loss=loss_fn
    )

    # ── TRAIN ──
    epoch_losses = []
    pbar = tqdm(
        train_ds,
        total=steps_per_epoch,
        desc=f"Train Epoch {epoch_idx+1}/{EPOCHS}",
        unit="batch",
        ncols=110
    )

    for step, (imgs, labels) in enumerate(pbar):
        label_inp = tf.expand_dims(labels, -1)
        loss_val = train_model.train_on_batch([imgs, label_inp], labels)
        epoch_losses.append(loss_val)

        # current LR (schedule-safe)
        lr = train_model.optimizer.learning_rate
        current_lr = (
            float(lr(train_model.optimizer.iterations))
            if isinstance(lr, tf.keras.optimizers.schedules.LearningRateSchedule)
            else float(tf.keras.backend.get_value(lr))
        )

        pbar.set_postfix({
            "loss": f"{loss_val:.4f}",
            "lr": f"{current_lr:.2e}"
        })

    avg_train_loss = float(np.mean(epoch_losses))
    history['train_loss'].append(avg_train_loss)
    history['lr'].append(current_lr)

    # ── VAL LOSS ──
    val_losses = []
    for imgs, labels in val_ds:
        label_inp = tf.expand_dims(labels, -1)
        vl = train_model.evaluate([imgs, label_inp], labels, verbose=0)
        val_losses.append(vl)

    avg_val_loss = float(np.mean(val_losses))
    history['val_loss'].append(avg_val_loss)

    # ── VAL AUC ──
    auc_score = compute_val_auc(n_pairs=5000)
    history['val_auc'].append(auc_score)

    elapsed = (time.time() - epoch_start) / 60.0

    print(
        f"  Ep {epoch_idx+1:02d} | "
        f"train_loss={avg_train_loss:.4f} | "
        f"val_loss={avg_val_loss:.4f} | "
        f"val_AUC={auc_score:.4f} | "
        f"lr={current_lr:.2e} | "
        f"time={elapsed:.1f} min"
    )

    # ── Checkpoint ──
    if auc_score > best_auc:
        best_auc = auc_score
        patience_counter = 0
        embedding_model.save_weights(os.path.join(SAVE_DIR, 'best_embedding.weights.h5'))
        train_model.save_weights(os.path.join(SAVE_DIR, 'best_train_model.weights.h5'))
        print(f"  ✓ New best AUC → {best_auc:.4f}")
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            return False  # early stop

    return True

print("✓ Training loop fixed and ready. Run Cell 11.")

# %%
# ============================================================
# CELL 10  –  compute_val_auc()  — used inside the training loop
# ============================================================

def extract_all_embeddings(dataset, model):
    """Push every batch through the embedding model (no ArcFace)."""
    all_emb, all_lbl = [], []
    for imgs, labels in dataset:
        emb = model(imgs, training=False)            # BN uses moving stats
        all_emb.append(emb.numpy())
        all_lbl.append(labels.numpy())
    return np.concatenate(all_emb), np.concatenate(all_lbl)


def compute_val_auc(n_pairs=5000):
    """
    1. Extract embeddings for ALL val images.
    2. Sample n_pairs positive + n_pairs negative pairs.
    3. Return ROC-AUC on cosine similarities.
    """
    embs, labels = extract_all_embeddings(val_ds, embedding_model)

    # group indices by identity
    id2idx = {}
    for i, lbl in enumerate(labels):
        id2idx.setdefault(int(lbl), []).append(i)
    ids = list(id2idx.keys())

    sims, gts = [], []

    # ── positive pairs (same identity) ──
    for _ in range(n_pairs):
        lbl  = random.choice(ids)
        i, j = random.sample(id2idx[lbl], 2)
        sims.append(float(embs[i] @ embs[j]))
        gts.append(1)

    # ── negative pairs (different identities) ──
    for _ in range(n_pairs):
        a, b = random.sample(ids, 2)
        i    = random.choice(id2idx[a])
        j    = random.choice(id2idx[b])
        sims.append(float(embs[i] @ embs[j]))
        gts.append(0)

    return roc_auc_score(gts, sims)

print("compute_val_auc() defined.")

# %%
# ============================================================
# CELL 11  –  Execute training
# ============================================================
print(f"Starting training … | Epochs={EPOCHS} | Batch={BATCH_SIZE} | Patience={PATIENCE}")
print(f"Train images : {len(train_files)}   Val images : {len(val_files)}\n")

for epoch in range(EPOCHS):
    print(f"Epoch {epoch+1}/{EPOCHS}")
    should_continue = run_epoch(epoch)
    if not should_continue:
        print(f"\n⏹ Early stopping at epoch {epoch+1}. Best val AUC = {best_auc:.4f}")
        break
else:
    print(f"\n✓ Training complete. Best val AUC = {best_auc:.4f}")

# ── reload best weights ──
embedding_model.load_weights(os.path.join(SAVE_DIR, 'best_embedding.weights.h5'))
print("Best embedding weights restored.")

# %%
# ============================================================
# CELL 12  –  Full evaluation  (AUC, EER, TAR@FAR, Accuracy)
# ============================================================

N_EVAL_PAIRS = 20_000                                  # per class (pos / neg)

# ── 1. Extract embeddings ──
val_embs, val_lbls = extract_all_embeddings(val_ds, embedding_model)
print(f"Extracted {val_embs.shape[0]} embeddings  dim={val_embs.shape[1]}")

# ── 2. Sample pairs ──
id2idx = {}
for i, lbl in enumerate(val_lbls):
    id2idx.setdefault(int(lbl), []).append(i)
ids = list(id2idx.keys())

sims, gts = [], []
for _ in range(N_EVAL_PAIRS):          # positives
    lbl  = random.choice(ids)
    i, j = random.sample(id2idx[lbl], 2)
    sims.append(float(val_embs[i] @ val_embs[j]))
    gts.append(1)
for _ in range(N_EVAL_PAIRS):          # negatives
    a, b = random.sample(ids, 2)
    i    = random.choice(id2idx[a])
    j    = random.choice(id2idx[b])
    sims.append(float(val_embs[i] @ val_embs[j]))
    gts.append(0)

sims = np.array(sims)
gts  = np.array(gts)

# ── 3. ROC ──
fpr, tpr, thresholds = roc_curve(gts, sims)
auc_score = roc_auc_score(gts, sims)

# ── 4. EER ──
fnr = 1 - tpr
abs_diff = np.abs(fnr - fpr)
eer_idx  = np.argmin(abs_diff)
eer       = (fpr[eer_idx] + fnr[eer_idx]) / 2.0
eer_thresh = thresholds[eer_idx]

# ── 5. TAR @ FAR ──
def tar_at_far(target_far):
    idx = np.argmin(np.abs(fpr - target_far))
    return tpr[idx]

tar_1e4 = tar_at_far(1e-4)
tar_1e3 = tar_at_far(1e-3)

# ── 6. Verification accuracy at EER threshold ──
preds = (sims >= eer_thresh).astype(int)
ver_acc = np.mean(preds == gts)

# ── Print summary ──
print("\n" + "="*48)
print("        EVALUATION SUMMARY  (108 unseen IDs)")
print("="*48)
print(f"  ROC-AUC              :  {auc_score:.6f}")
print(f"  EER                 :  {eer*100:.2f} %")
print(f"  EER threshold       :  {eer_thresh:.4f}")
print(f"  TAR @ FAR=1e-4      :  {tar_1e4:.4f}")
print(f"  TAR @ FAR=1e-3      :  {tar_1e3:.4f}")
print(f"  Verification Acc    :  {ver_acc*100:.2f} %")
print("="*48)

# ── persist for plotting ──
eval_results = dict(fpr=fpr, tpr=tpr, thresholds=thresholds,
                    auc=auc_score, eer=eer, eer_thresh=eer_thresh,
                    tar_1e4=tar_1e4, tar_1e3=tar_1e3, ver_acc=ver_acc,
                    sims=sims, gts=gts)

# %%
# ============================================================
# CELL 13  –  Plot 1  →  ROC Curve  +  EER annotation
# ============================================================
fig, ax = plt.subplots(figsize=(8, 6.5))
fig.patch.set_facecolor('#0e0f14')
ax.set_facecolor('#16171e')

# ── ROC curve ──
ax.plot(eval_results['fpr'], eval_results['tpr'],
       color='#5b8cff', linewidth=2.2, label=f"AUC = {eval_results['auc']:.4f}")

# ── diagonal (random) ──
ax.plot([0, 1], [0, 1], '--', color='#3a3c4a', linewidth=1)

# ── EER point ──
eer_val = eval_results['eer']
ax.scatter([eer_val], [1 - eer_val], s=80, color='#f06482', zorder=5, edgecolors='#0e0f14', linewidths=2)
ax.annotate(
    f"EER = {eer_val*100:.2f} %",
    xy=(eer_val, 1 - eer_val),
    xytext=(eer_val + 0.06, 1 - eer_val - 0.08),
    fontsize=11, color='#f06482', fontweight='bold',
    arrowprops=dict(arrowstyle='->', color='#f06482')
)

# ── TAR @ FAR markers ──
for far_target, label_t, clr in [
    (1e-4, 'FAR=1e-4', '#34e8b0'),
    (1e-3, 'FAR=1e-3', '#ffc15e')
]:
    idx = np.argmin(np.abs(eval_results['fpr'] - far_target))
    ax.scatter([eval_results['fpr'][idx]], [eval_results['tpr'][idx]],
            s=60, color=clr, zorder=5, edgecolors='#0e0f14', linewidths=1.5)
    ax.annotate(f"{label_t}\nTAR={eval_results['tpr'][idx]:.3f}",
            xy=(eval_results['fpr'][idx], eval_results['tpr'][idx]),
            xytext=(eval_results['fpr'][idx] + 0.04, eval_results['tpr'][idx] - 0.06),
            fontsize=9, color=clr,
            arrowprops=dict(arrowstyle='->', color=clr))

# ── styling ──
ax.set_xlabel('False Positive Rate', fontsize=12, color='#8b90a0')
ax.set_ylabel('True Positive Rate', fontsize=12, color='#8b90a0')
ax.set_title('ROC Curve — Face Verification (108 Unseen Identities)',
           fontsize=14, color='#fff', pad=14)
ax.tick_params(colors='#8b90a0')
for sp in ax.spines.values(): sp.set_color('#2a2c38')
leg = ax.legend(loc='lower right', fontsize=11,
              facecolor='#1e1f2b', edgecolor='#2a2c38', labelcolor='#cdd1dc')
ax.set_xlim(-0.02, 1.02); ax.set_ylim(-0.02, 1.02)
ax.grid(True, color='#2a2c38', linestyle='--', alpha=0.4)

plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, 'plot_roc.png'), dpi=150)
plt.show()

# %%
# ============================================================
# CELL 14  –  Plot 2  →  Training / Val Loss  +  Val AUC  +  LR
# ============================================================
epochs_ran = len(history['train_loss'])
x_ax = np.arange(1, epochs_ran + 1)

fig, axes = plt.subplots(2, 1, figsize=(10, 7), gridspec_kw={'hspace': 0.35})
fig.patch.set_facecolor('#0e0f14')

# ── top: losses ──
ax = axes[0]
ax.set_facecolor('#16171e')
ax.plot(x_ax, history['train_loss'], color='#5b8cff', lw=2, label='Train Loss')
ax.plot(x_ax, history['val_loss'],   color='#f06482', lw=2, label='Val Loss')
ax.axvline(WARMUP_EPOCHS, color='#ffc15e', ls='--', lw=1, alpha=0.7)
ax.text(WARMUP_EPOCHS + 0.3, max(history['train_loss']) * 0.95,
       'backbone unfrozen', color='#ffc15e', fontsize=9)
ax.set_ylabel('Loss', color='#8b90a0', fontsize=11)
ax.set_title('Training Dynamics', color='#fff', fontsize=14, pad=10)
ax.tick_params(colors='#8b90a0')
for sp in ax.spines.values(): sp.set_color('#2a2c38')
ax.legend(facecolor='#1e1f2b', edgecolor='#2a2c38', labelcolor='#cdd1dc')
ax.grid(True, color='#2a2c38', ls='--', alpha=0.4)

# ── bottom-left: val AUC ──
ax2 = axes[1]
ax2.set_facecolor('#16171e')
ax2.plot(x_ax, history['val_auc'], color='#34e8b0', lw=2.2, label='Val AUC-ROC')
ax2.axhline(best_auc, color='#34e8b0', ls=':', lw=1, alpha=0.5)
ax2.text(1, best_auc + 0.002, f'best = {best_auc:.4f}', color='#34e8b0', fontsize=9)
ax2.set_ylabel('AUC-ROC', color='#8b90a0', fontsize=11)
ax2.set_xlabel('Epoch', color='#8b90a0', fontsize=11)
ax2.tick_params(colors='#8b90a0')
for sp in ax2.spines.values(): sp.set_color('#2a2c38')
ax2.legend(facecolor='#1e1f2b', edgecolor='#2a2c38', labelcolor='#cdd1dc')
ax2.grid(True, color='#2a2c38', ls='--', alpha=0.4)

# ── LR on a twin axis ──
ax3 = ax2.twinx()
ax3.plot(x_ax, history['lr'], color='#ffc15e', lw=1.2, ls='--', label='LR')
ax3.set_ylabel('Learning Rate', color='#ffc15e', fontsize=10)
ax3.tick_params(colors='#ffc15e')
ax3.set_facecolor('#16171e')
for sp in ax3.spines.values(): sp.set_color('#2a2c38')
lines3, labels3 = ax3.get_legend_handles_labels()
ax2.legend(ax2.get_legend_handles_labels()[0] + lines3,
           ax2.get_legend_handles_labels()[1] + labels3,
           facecolor='#1e1f2b', edgecolor='#2a2c38', labelcolor='#cdd1dc')

plt.savefig(os.path.join(SAVE_DIR, 'plot_history.png'), dpi=150)
plt.show()

# %%
# ============================================================
# CELL 15  –  Plot 3  →  Cosine-similarity distributions
# ============================================================
pos_sims = eval_results['sims'][eval_results['gts'] == 1]
neg_sims = eval_results['sims'][eval_results['gts'] == 0]

fig, ax = plt.subplots(figsize=(9, 5))
fig.patch.set_facecolor('#0e0f14')
ax.set_facecolor('#16171e')

bins = np.linspace(-0.4, 1.0, 120)
ax.hist(neg_sims, bins=bins, density=True, alpha=0.55,
       color='#f06482', label='Negative (diff identity)', edgecolor='none')
ax.hist(pos_sims, bins=bins, density=True, alpha=0.55,
       color='#34e8b0', label='Positive (same identity)', edgecolor='none')

# ── EER threshold line ──
ax.axvline(eval_results['eer_thresh'], color='#ffc15e', ls='--', lw=2)
ax.text(eval_results['eer_thresh'] + 0.01, ax.get_ylim()[1] * 0.9,
       f"threshold = {eval_results['eer_thresh']:.3f}", color='#ffc15e', fontsize=10)

ax.set_xlabel('Cosine Similarity', color='#8b90a0', fontsize=12)
ax.set_ylabel('Density',           color='#8b90a0', fontsize=12)
ax.set_title('Pair-wise Similarity: Positive vs Negative', color='#fff', fontsize=14, pad=12)
ax.tick_params(colors='#8b90a0')
for sp in ax.spines.values(): sp.set_color('#2a2c38')
ax.legend(facecolor='#1e1f2b', edgecolor='#2a2c38', labelcolor='#cdd1dc', fontsize=11)
ax.grid(True, color='#2a2c38', ls='--', alpha=0.4)

plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, 'plot_sim_dist.png'), dpi=150)
plt.show()

# %%
# ============================================================
# CELL 16  –  Plot 4  →  UMAP cluster visualisation
# ============================================================
# !pip install umap-learn   ← uncomment if needed on Kaggle
import umap

# ── subsample for speed (optional: use all val_embs) ──
MAX_PER_ID  = 30                                    # images per identity to plot
subset_idx  = []
for lbl, idxs in id2idx.items():
    subset_idx.extend(random.sample(idxs, min(MAX_PER_ID, len(idxs))))
subset_embs = val_embs[subset_idx]
subset_lbls = val_lbls[subset_idx]

# ── UMAP projection ──
reducer = umap.UMAP(
    n_components=2, n_neighbors=15,
    min_dist=0.08, metric='cosine', random_state=SEED
)
coords = reducer.fit_transform(subset_embs)
print(f"UMAP done  →  {coords.shape}")

# ── Plot ──
fig, ax = plt.subplots(figsize=(11, 9))
fig.patch.set_facecolor('#0e0f14')
ax.set_facecolor('#10111a')

# ── colour map: use enough distinct colours ──
n_unique = len(np.unique(subset_lbls))
cmap     = plt.cm.get_cmap('tab20', n_unique)

scatter = ax.scatter(
    coords[:, 0], coords[:, 1],
    c=subset_lbls, cmap=cmap, s=18, alpha=0.75,
    edgecolors='#0e0f14', linewidths=0.6
)

ax.set_xlabel('UMAP-1', color='#8b90a0', fontsize=11)
ax.set_ylabel('UMAP-2', color='#8b90a0', fontsize=11)
ax.set_title(
    f'Embedding Space — {len(np.unique(subset_lbls))} Unseen Identities  '
    f'(UMAP · cosine)',
    color='#fff', fontsize=15, pad=14
)
ax.tick_params(colors='#8b90a0')
for sp in ax.spines.values(): sp.set_color('#2a2c38')
ax.grid(True, color='#1e1f2b', ls='-', alpha=0.35)

# ── legend-free note ──
ax.text(ax.get_xlim()[0] + 0.2, ax.get_ylim()[0] + 0.3,
       'Each colour = one identity', color='#6b7280', fontsize=10, style='italic')

plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, 'plot_umap.png'), dpi=150)
plt.show()

# %%
# ============================================================
# CELL 17  –  Plot 5  →  DET curve  (log-log FPR vs FNR)
# ============================================================
fpr_det = eval_results['fpr']
fnr_det = 1 - eval_results['tpr']

# clip to avoid log(0)
eps      = 1e-5
fpr_clip = np.clip(fpr_det, eps, 1)
fnr_clip = np.clip(fnr_det, eps, 1)

fig, ax = plt.subplots(figsize=(7.5, 6))
fig.patch.set_facecolor('#0e0f14')
ax.set_facecolor('#16171e')

ax.loglog(fpr_clip, fnr_clip, color='#5b8cff', linewidth=2.2)

# ── EER marker ──
ax.scatter([eer_val], [eer_val], s=70, color='#f06482',
           zorder=5, edgecolors='#0e0f14', linewidths=2)
ax.annotate(f'EER = {eer_val*100:.2f} %', xy=(eer_val, eer_val),
            xytext=(eer_val * 4, eer_val * 0.25),
            color='#f06482', fontsize=11, fontweight='bold',
            arrowprops=dict(arrowstyle='->', color='#f06482'))

# ── random baseline ──
ax.loglog([eps, 1], [eps, 1], '--', color='#3a3c4a', lw=1, label='Random')

ax.set_xlabel('False Positive Rate', color='#8b90a0', fontsize=11)
ax.set_ylabel('False Negative Rate', color='#8b90a0', fontsize=11)
ax.set_title('DET Curve', color='#fff', fontsize=14, pad=12)
ax.tick_params(colors='#8b90a0', which='both')
for sp in ax.spines.values(): sp.set_color('#2a2c38')
ax.legend(facecolor='#1e1f2b', edgecolor='#2a2c38', labelcolor='#cdd1dc')
ax.grid(True, color='#2a2c38', which='both', ls='--', alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, 'plot_det.png'), dpi=150)
plt.show()

# %%
# ============================================================
# CELL 18  –  Plot 6  →  Metric summary card  (bar chart)
# ============================================================
metrics = {
    'AUC-ROC':       eval_results['auc'],
    'Verify Acc':    eval_results['ver_acc'],
    'TAR@FAR1e-3':  eval_results['tar_1e3'],
    'TAR@FAR1e-4':  eval_results['tar_1e4'],
    '1 − EER':       1 - eval_results['eer'],
}

fig, ax = plt.subplots(figsize=(9, 4))
fig.patch.set_facecolor('#0e0f14')
ax.set_facecolor('#16171e')

colors = ['#5b8cff', '#34e8b0', '#ffc15e', '#f06482', '#a78bfa']
bars   = ax.barh(list(metrics.keys()), list(metrics.values()),
            color=colors, height=0.45, edgecolor='none')

# ── value labels ──
for bar, val in zip(bars, metrics.values()):
    ax.text(val + 0.005, bar.get_y() + bar.get_height() / 2,
           f'{val*100:.2f} %', va='center', color='#fff', fontsize=12, fontweight='bold')

# ── target line at 1.0 ──
ax.axvline(1.0, color='#2a2c38', ls='--', lw=1)
ax.set_xlim(0.7, 1.04)
ax.set_xlabel('Score', color='#8b90a0', fontsize=11)
ax.set_title('Evaluation Metrics — 108 Unseen Identities', color='#fff', fontsize=14, pad=12)
ax.tick_params(colors='#8b90a0')
for sp in ax.spines.values(): sp.set_color('#2a2c38')
ax.grid(True, color='#2a2c38', ls='--', alpha=0.4, axis='x')

plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, 'plot_metrics.png'), dpi=150)
plt.show()

# %%
# ============================================================
# CELL 19  –  Export the embedding model  (no ArcFace head)
# ============================================================

# ── 1. Keras SavedModel ──
saved_path = os.path.join(SAVE_DIR, 'face_embedding_savedmodel')
embedding_model.save(saved_path)
print(f"✓ SavedModel  →  {saved_path}")

# ── 2. H5 weights only (lightest) ──
h5_path = os.path.join(SAVE_DIR, 'face_embedding_weights.h5')
embedding_model.save_weights(h5_path)
print(f"✓ Weights H5  →  {h5_path}")

# ── 3. ONNX  (optional — uncomment if tf2onnx is available) ──
# !pip install tf2onnx onnx
# import tf2onnx, onnx
# spec = [tf.TensorSpec(shape=[1,112,112,3], dtype=tf.float32)]
# onnx_model, _ = tf2onnx.convert.from_keras(embedding_model, input_signature=spec)
# onnx.save(onnx_model, os.path.join(SAVE_DIR, 'face_embedding.onnx'))
# print("✓ ONNX model saved")

# ── 4. Quick inference smoke-test ──
dummy = np.random.randn(1, 112, 112, 3).astype(np.float32)
out   = embedding_model.predict(dummy)
print(f"\n✓ Smoke test → output shape: {out.shape}, L2-norm: {np.linalg.norm(out, axis=1)}")
