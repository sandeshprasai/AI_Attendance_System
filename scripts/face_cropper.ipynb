# %%
import cv2
import mediapipe as mp
import os

# Initialize Mediapipe face detector
mp_face_detection = mp.solutions.face_detection
detector = mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5)

# Input (raw dataset) and output (cropped faces) directories
input_dir = r"D:\Final_Year_Major_Project\Data_Sets_Collection - Copy\images"
output_dir = r"D:\Final_Year_Major_Project\faces"

os.makedirs(output_dir, exist_ok=True)

# Loop through each person’s folder
for person_name in os.listdir(input_dir):
    person_path = os.path.join(input_dir, person_name)
    if not os.path.isdir(person_path):
        continue  # skip if not a folder

    # Create corresponding output folder
    person_output = os.path.join(output_dir, person_name)
    os.makedirs(person_output, exist_ok=True)

    # Loop through each image in the folder
    for img_name in os.listdir(person_path):
        img_path = os.path.join(person_path, img_name)
        img = cv2.imread(img_path)

        if img is None:
            continue

        # Convert to RGB for Mediapipe
        rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = detector.process(rgb)

        if not results.detections:
            continue  # skip if no face found

        # Find the largest face
        largest = max(
            results.detections,
            key=lambda det: det.location_data.relative_bounding_box.width *
                            det.location_data.relative_bounding_box.height
        )

        # Extract bounding box
        box = largest.location_data.relative_bounding_box
        h, w, _ = img.shape
        x, y = int(box.xmin * w), int(box.ymin * h)
        bw, bh = int(box.width * w), int(box.height * h)

        # Ensure bounding box stays within image boundaries
        x, y = max(0, x), max(0, y)
        face = img[y:y+bh, x:x+bw]

        # Resize to 224x224
        face = cv2.resize(face, (224, 224))

        # Save cropped face in corresponding folder
        out_path = os.path.join(person_output, img_name)
        cv2.imwrite(out_path, face)

print("✅ Cropping completed! Faces saved in:", output_dir)

# %%
# !pip uninstall -y tensorflow mtcnn
# !pip install protobuf==3.20.*
# !pip install mediapipe opencv-python

# %%
# !pip uninstall -y numpy mediapipe matplotlib

# %%
# !pip install numpy==1.26.4
# !pip install matplotlib==3.8.1
# !pip install mediapipe==0.10.21
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy==1.26.4 in c:\programdata\anaconda3\lib\site-packages (1.26.4)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib==3.8.1
#   Downloading matplotlib-3.8.1-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (24.1)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib==3.8.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.8.1) (1.16.0)
# Downloading matplotlib-3.8.1-cp312-cp312-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.6 MB 5.6 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.6 MB 8.4 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.6 MB 8.7 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.6 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 9.3 MB/s eta 0:00:00
# Installing collected packages: matplotlib
# Successfully installed matplotlib-3.8.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mediapipe==0.10.21
#   Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: absl-py in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe==0.10.21) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (25.2.10)
# Requirement already satisfied: jax in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (0.7.1)
# Requirement already satisfied: jaxlib in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (0.7.1)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (3.8.1)
# Requirement already satisfied: numpy<2 in c:\programdata\anaconda3\lib\site-packages (from mediapipe==0.10.21) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\admin\appdata\roaming\python\python312\site-packages (from mediapipe==0.10.21) (0.2.1)
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe==0.10.21) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from jax->mediapipe==0.10.21) (0.5.3)
# Requirement already satisfied: opt_einsum in c:\users\admin\appdata\roaming\python\python312\site-packages (from jax->mediapipe==0.10.21) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\programdata\anaconda3\lib\site-packages (from jax->mediapipe==0.10.21) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe==0.10.21) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe==0.10.21) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe==0.10.21) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe==0.10.21) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe==0.10.21) (24.1)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe==0.10.21) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe==0.10.21) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe==0.10.21) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.21) (2.21)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.21) (1.16.0)
# Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl (51.0 MB)
# Installing collected packages: mediapipe
# Successfully installed mediapipe-0.10.21
